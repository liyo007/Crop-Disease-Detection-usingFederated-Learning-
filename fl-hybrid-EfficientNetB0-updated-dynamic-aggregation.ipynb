# %%
# Cell 1: Install required packages for maize disease detection
# !pip install flwr torch torchvision timm kagglehub opencv-python scikit-learn matplotlib seaborn pandas albumentations --quiet

print("All dependencies installed successfully for maize disease detection!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.6/617.6 kB 10.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.0 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 18.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 1.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 1.34.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.25.8 which is incompatible.
# google-spark-connect 0.5.2 requires google-api-core>=2.19.1, but you have google-api-core 1.34.1 which is incompatible.
# google-cloud-bigtable 2.30.0 requires google-api-core[grpc]<3.0.0,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# google-cloud-storage 2.19.0 requires google-api-core<3.0.0dev,>=2.15.0, but you have google-api-core 1.34.1 which is incompatible.
# pandas-gbq 0.28.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# All dependencies installed successfully for maize disease detection!

# %%
# !pip install scikit-image efficientnet_pytorch --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for efficientnet_pytorch (setup.py) ... done

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset, random_split
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import torchvision.models as models

import numpy as np
import pandas as pd
import cv2
from PIL import Image# Cell 2: Import libraries and basic setup for maize disease detection
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
from torchvision.datasets import ImageFolder
from torchvision import transforms
import timm
import flwr as fl
from flwr.client import NumPyClient
from flwr.server.strategy import FedAvg
from flwr.common import ndarrays_to_parameters, parameters_to_ndarrays
from collections import defaultdict, OrderedDict
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image, ImageEnhance, ImageFilter  # Added missing imports
import cv2
from skimage import exposure, filters
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
    print(f"CUDA Version: {torch.version.cuda}")
else:
    print("CUDA not available. Running on CPU.")

print("Setup completed for maize disease detection federated learning!")

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import os
import random
import time
import copy
from collections import defaultdict, OrderedDict
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# 2025-09-05 09:00:38.515502: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757062838.870040      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757062838.975483      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using device: cuda
# CUDA available: True
# GPU: Tesla T4
# GPU Memory: 14.7 GB
# CUDA Version: 12.4
# Setup completed for maize disease detection federated learning!
# Using device: cuda

# %%
# Cell 3: Download dataset and configure maize-specific paths
import kagglehub
import os
try:
    # Download the dataset
    path = kagglehub.dataset_download("irakozekelly/crop-pest-and-disease-dataset")
    print("Path to dataset files:", path)

    # Set maize-specific dataset paths as per your requirement
    DATASET_BASE_PATH = os.path.join(path, "Dataset for Crop Pest and Disease Detection", "CCMT Dataset-Augmented", "Maize")
    TRAIN_PATH = os.path.join(DATASET_BASE_PATH, "train_set")
    TEST_PATH = os.path.join(DATASET_BASE_PATH, "test_set")

    print(f"\nMaize Dataset Paths:")
    print(f"Base Path: {DATASET_BASE_PATH}")
    print(f"Train Path: {TRAIN_PATH}")
    print(f"Test Path: {TEST_PATH}")

except Exception as e:
    print(f"Error downloading dataset: {e}")
    print("Please manually set the dataset paths:")
    path = input("Enter base dataset path: ")
    DATASET_BASE_PATH = os.path.join(path, "Dataset for Crop Pest and Disease Detection", "CCMT Dataset-Augmented", "Maize")
    TRAIN_PATH = os.path.join(DATASET_BASE_PATH, "train_set")
    TEST_PATH = os.path.join(DATASET_BASE_PATH, "test_set")

# Verify maize dataset paths exist
print(f"\nPath Verification:")
print(f"Base path exists: {os.path.exists(DATASET_BASE_PATH)}")
print(f"Train path exists: {os.path.exists(TRAIN_PATH)}")
print(f"Test path exists: {os.path.exists(TEST_PATH)}")

# List maize disease classes
if os.path.exists(TRAIN_PATH):
    maize_classes = sorted([d for d in os.listdir(TRAIN_PATH) if os.path.isdir(os.path.join(TRAIN_PATH, d))])
    print(f"\nMaize Disease Classes Found: {maize_classes}")
    print(f"Number of maize disease classes: {len(maize_classes)}")
else:
    print("Warning: Train path not found. Please check the dataset structure.")
# Out:
# Path to dataset files: /kaggle/input/
#
# Maize Dataset Paths:
# Base Path: /kaggle/input/Dataset for Crop Pest and Disease Detection/CCMT Dataset-Augmented/Maize
# Train Path: /kaggle/input/Dataset for Crop Pest and Disease Detection/CCMT Dataset-Augmented/Maize/train_set
# Test Path: /kaggle/input/Dataset for Crop Pest and Disease Detection/CCMT Dataset-Augmented/Maize/test_set
#
# Path Verification:
# Base path exists: True
# Train path exists: True
# Test path exists: True
#
# Maize Disease Classes Found: ['fall armyworm', 'grasshoper', 'healthy', 'leaf beetle', 'leaf blight', 'leaf spot', 'streak virus']
# Number of maize disease classes: 7

# %%
# Cell 4: Optimized image enhancement for maize disease detection with CCMT dataset
import cv2
import numpy as np
from PIL import Image, ImageFilter
from skimage import restoration

class MaizeDiseaseImageEnhancer:
    def __init__(self):
        pass

    def apply_clahe(self, image, clip_limit=2.0, tile_grid_size=(8,8)):
        """
        CLAHE (Contrast Limited Adaptive Histogram Equalization)
        Essential for enhancing local contrast in disease spots
        """
        img_array = np.array(image)
        lab = cv2.cvtColor(img_array, cv2.COLOR_RGB2LAB)
        l, a, b = cv2.split(lab)
        clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
        cl = clahe.apply(l)
        enhanced_lab = cv2.merge((cl, a, b))
        enhanced_rgb = cv2.cvtColor(enhanced_lab, cv2.COLOR_LAB2RGB)
        return Image.fromarray(enhanced_rgb)

    def denoise_image(self, image, method='gaussian'):
        """
        Noise reduction for CCMT dataset images
        Essential for removing sensor noise and compression artifacts
        """
        img_array = np.array(image)
        
        if method == 'gaussian':
            # Gaussian blur for general noise reduction
            denoised = cv2.GaussianBlur(img_array, (3, 3), 0.8)
        elif method == 'bilateral':
            # Bilateral filter - preserves edges while reducing noise
            denoised = cv2.bilateralFilter(img_array, 9, 75, 7x5)
        elif method == 'non_local_means':
            # Non-local means denoising - more advanced but slower
            denoised = cv2.fastNlMeansDenoisingColored(img_array, None, 10, 10, 7, 21)
        else:
            # Default to median filter for salt-and-pepper noise
            denoised = cv2.medianBlur(img_array, 3)
            
        return Image.fromarray(denoised)

    def enhance(self, image, train_mode=True):
        """
        Streamlined enhancement pipeline for CCMT maize disease dataset
        """
        # Step 1: Noise reduction (always applied for CCMT dataset quality)
        enhanced = self.denoise_image(image, method='gaussian')
        
        # Step 2: CLAHE for contrast enhancement (essential for disease detection)
        enhanced = self.apply_clahe(enhanced, clip_limit=2.0, tile_grid_size=(8,8))
        
        # Step 3: Additional denoising during training for robustness
        if train_mode and np.random.rand() < 0.3:
            enhanced = self.denoise_image(enhanced, method='bilateral')
            
        return enhanced

maize_enhancer = MaizeDiseaseImageEnhancer()
print("Optimized maize disease image enhancement system with noise reduction initialized!")
# Out:
# Optimized maize disease image enhancement system with noise reduction initialized!

# %%
class MaizeDiseaseTransforms:
    def __init__(self, image_size=224):
        self.image_size = image_size
        self.enhancer = maize_enhancer

    def maize_train_transform(self):
        return transforms.Compose([
            transforms.Lambda(lambda img: self.enhancer.enhance(img, train_mode=True)),
            transforms.Resize((self.image_size, self.image_size)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomVerticalFlip(p=0.3),
            transforms.RandomRotation(degrees=15),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2, hue=0.1),
            transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1), shear=5),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

    def maize_test_transform(self):
        return transforms.Compose([
            transforms.Lambda(lambda img: self.enhancer.enhance(img, train_mode=False)),
            transforms.Resize((self.image_size, self.image_size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

maize_transforms = MaizeDiseaseTransforms(image_size=224)
transform_train = maize_transforms.maize_train_transform()
transform_test = maize_transforms.maize_test_transform()
print("Maize disease-aware transforms initialized!")
# Out:
# Maize disease-aware transforms initialized!

# %%
# Cell 6: Load and analyze maize disease dataset
def analyze_maize_dataset(dataset_path):
    """Analyze maize disease dataset structure and class distribution"""
    maize_classes = []
    class_counts = {}

    if os.path.exists(dataset_path):
        maize_classes = sorted([d for d in os.listdir(dataset_path)
                               if os.path.isdir(os.path.join(dataset_path, d))])

        for class_name in maize_classes:
            class_path = os.path.join(dataset_path, class_name)
            count = len([f for f in os.listdir(class_path)
                        if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
            class_counts[class_name] = count

    return maize_classes, class_counts

# Load maize disease datasets
print("Loading maize disease datasets with enhanced transforms...")
maize_train_dataset = ImageFolder(root=TRAIN_PATH, transform=transform_train)
maize_test_dataset = ImageFolder(root=TEST_PATH, transform=transform_test)

# Analyze maize disease datasets
train_classes, train_counts = analyze_maize_dataset(TRAIN_PATH)
test_classes, test_counts = analyze_maize_dataset(TEST_PATH)

print(f"\nMaize Disease Dataset Analysis:")
print(f"{'='*50}")
print(f"Train Dataset:")
print(f"  Maize disease classes: {train_classes}")
print(f"  Class distribution: {train_counts}")
print(f"  Total training samples: {sum(train_counts.values())}")

print(f"\nTest Dataset:")
print(f"  Maize disease classes: {test_classes}")
print(f"  Class distribution: {test_counts}")
print(f"  Total test samples: {sum(test_counts.values())}")

# Set global variables for maize disease detection
NUM_MAIZE_CLASSES = len(maize_train_dataset.classes)
MAIZE_CLASS_NAMES = maize_train_dataset.classes

print(f"\nMaize Disease Detection Configuration:")
print(f"  Number of maize disease classes: {NUM_MAIZE_CLASSES}")
print(f"  Maize disease class names: {MAIZE_CLASS_NAMES}")

# Create test dataloader for maize diseases
maize_test_loader = DataLoader(maize_test_dataset, batch_size=64, shuffle=False, num_workers=2)

# Visualize class distribution
plt.figure(figsize=(12, 6))
plt.bar(MAIZE_CLASS_NAMES, [train_counts[cls] for cls in MAIZE_CLASS_NAMES])
plt.title('Maize Disease Class Distribution in Training Set', fontsize=14, fontweight='bold')
plt.xlabel('Maize Disease Classes', fontsize=12)
plt.ylabel('Number of Samples', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Loading maize disease datasets with enhanced transforms...
#
# Maize Disease Dataset Analysis:
# ==================================================
# Train Dataset:
#   Maize disease classes: ['fall armyworm', 'grasshoper', 'healthy', 'leaf beetle', 'leaf blight', 'leaf spot', 'streak virus']
#   Class distribution: {'fall armyworm': 1140, 'grasshoper': 2575, 'healthy': 830, 'leaf beetle': 3789, 'leaf blight': 4025, 'leaf spot': 3024, 'streak virus': 4043}
#   Total training samples: 19426
#
# Test Dataset:
#   Maize disease classes: ['fall armyworm', 'grasshoper', 'healthy', 'leaf beetle', 'leaf blight', 'leaf spot', 'streak virus']
#   Class distribution: {'fall armyworm': 284, 'grasshoper': 411, 'healthy': 211, 'leaf beetle': 950, 'leaf blight': 1004, 'leaf spot': 1261, 'streak virus': 1004}
#   Total test samples: 5125
#
# Maize Disease Detection Configuration:
#   Number of maize disease classes: 7
#   Maize disease class names: ['fall armyworm', 'grasshoper', 'healthy', 'leaf beetle', 'leaf blight', 'leaf spot', 'streak virus']

# %%
# Cell 7 Option 1: Hybrid EfficientNet-B0 + MobileViT Architecture
import timm
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import OrderedDict
from efficientnet_pytorch import EfficientNet

# Enhanced Spatial Attention with dilated convolution
class EnhancedSpatialAttention(nn.Module):
    def __init__(self, kernel_size=7, dilation=1):
        super().__init__()
        padding = (kernel_size + (kernel_size - 1) * (dilation - 1)) // 2
        self.conv = nn.Sequential(
            nn.Conv2d(2, 1, kernel_size, padding=padding, dilation=dilation, bias=False),
            nn.BatchNorm2d(1),
            nn.Sigmoid()
        )

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        attention_input = torch.cat([avg_out, max_out], dim=1)
        attention = self.conv(attention_input)
        return x * attention

# Lightweight CBAM for EfficientNet features
class LightweightCBAM(nn.Module):
    def __init__(self, channels, reduction=16):
        super().__init__()
        self.channel_attention = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(channels, channels // reduction, 1, bias=False),
            nn.ReLU(inplace=True),
            nn.Conv2d(channels // reduction, channels, 1, bias=False),
            nn.Sigmoid()
        )
        self.spatial_attention = EnhancedSpatialAttention(kernel_size=7, dilation=2)

    def forward(self, x):
        ca = self.channel_attention(x)
        x = x * ca
        x = self.spatial_attention(x)
        return x

# MobileViT block optimized for EfficientNet features
class EfficientNetMobileViTBlock(nn.Module):
    def __init__(self, in_channels, embed_dim=144, num_heads=6, patch_size=2):
        super().__init__()
        self.patch_size = patch_size
        self.embed_dim = embed_dim

        # Local representation with EfficientNet-style convolutions
        self.local_rep = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, 3, padding=1, groups=in_channels, bias=False),
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Conv2d(in_channels, embed_dim, 1, bias=False),
            nn.BatchNorm2d(embed_dim),
            nn.SiLU()
        )

        # Transformer block
        self.norm1 = nn.LayerNorm(embed_dim)
        self.attn = nn.MultiheadAttention(
            embed_dim=embed_dim,
            num_heads=num_heads,
            dropout=0.1,
            batch_first=True
        )

        self.norm2 = nn.LayerNorm(embed_dim)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, embed_dim * 4),
            nn.SiLU(),
            nn.Dropout(0.1),
            nn.Linear(embed_dim * 4, embed_dim),
            nn.Dropout(0.1)
        )

        # Fusion back to original channels
        self.fusion = nn.Sequential(
            nn.Conv2d(embed_dim, in_channels, 1, bias=False),
            nn.BatchNorm2d(in_channels),
            nn.SiLU()
        )

    def forward(self, x):
        B, C, H, W = x.shape
        residual = x

        # Pad if necessary
        pad_h = (self.patch_size - H % self.patch_size) % self.patch_size
        pad_w = (self.patch_size - W % self.patch_size) % self.patch_size

        if pad_h > 0 or pad_w > 0:
            x = F.pad(x, (0, pad_w, 0, pad_h))
            H, W = x.shape[2], x.shape[3]

        # Local representation
        local_features = self.local_rep(x)

        # Convert to patches
        patches = local_features.unfold(2, self.patch_size, self.patch_size).unfold(3, self.patch_size, self.patch_size)
        patches = patches.contiguous().view(B, self.embed_dim, -1, self.patch_size * self.patch_size)
        patches = patches.permute(0, 2, 3, 1).contiguous().view(B, -1, self.embed_dim)

        # Transformer processing
        patches_norm = self.norm1(patches)
        attn_out, _ = self.attn(patches_norm, patches_norm, patches_norm)
        patches = patches + attn_out

        patches_norm = self.norm2(patches)
        mlp_out = self.mlp(patches_norm)
        patches = patches + mlp_out

        # Reshape back to spatial
        num_patches_h = H // self.patch_size
        num_patches_w = W // self.patch_size
        patches = patches.view(B, num_patches_h, num_patches_w, self.patch_size, self.patch_size, self.embed_dim)
        patches = patches.permute(0, 5, 1, 3, 2, 4).contiguous()
        global_features = patches.view(B, self.embed_dim, H, W)

        # Fusion
        fused = self.fusion(global_features)

        # Crop back to original size
        if pad_h > 0 or pad_w > 0:
            fused = fused[:, :, :H-pad_h if pad_h > 0 else H, :W-pad_w if pad_w > 0 else W]
            residual = residual[:, :, :H-pad_h if pad_h > 0 else H, :W-pad_w if pad_w > 0 else W]

        return residual + fused

class EfficientNetB0MobileViT(nn.Module):
    """
    Hybrid EfficientNet-B0 + MobileViT for maize disease detection
    Combines EfficientNet's compound scaling with MobileViT's global attention
    """
    def __init__(self, num_classes):
        super().__init__()

        # EfficientNet-B0 backbone
        self.backbone = EfficientNet.from_pretrained('efficientnet-b0')
        self.backbone._fc = nn.Identity()

        # EfficientNet-B0 feature channels: 1280
        feature_channels = 1280

        # MobileViT block for global context
        self.mobile_vit = EfficientNetMobileViTBlock(
            in_channels=feature_channels,
            embed_dim=144,
            num_heads=6,
            patch_size=2
        )

        # CBAM attention
        self.cbam = LightweightCBAM(channels=feature_channels)

        # Classification head
        self.pool = nn.AdaptiveAvgPool2d(1)
        self.dropout = nn.Dropout(0.2)
        self.classifier = nn.Linear(feature_channels, num_classes)

        self._initialize_weights()

        total_params = sum(p.numel() for p in self.parameters())
        print(f"EfficientNet-B0 + MobileViT initialized:")
        print(f"  Total parameters: {total_params:,}")

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self, x):
        # Extract features using EfficientNet-B0
        x = self.backbone.extract_features(x)  # [B, 1280, H, W]

        # Apply MobileViT for global context
        x = self.mobile_vit(x)

        # Apply CBAM attention
        x = self.cbam(x)

        # Classification
        x = self.pool(x).flatten(1)
        x = self.dropout(x)
        x = self.classifier(x)
        return x

    def get_model_size(self):
        param_size = sum(p.numel() * p.element_size() for p in self.parameters())
        buffer_size = sum(b.numel() * b.element_size() for b in self.buffers())
        size_mb = (param_size + buffer_size) / 1024 / 1024
        return size_mb

    # def quantize_dynamic(self):
    #     import torch.quantization
    #     return torch.quantization.quantize_dynamic(self, {nn.Linear}, dtype=torch.qint8)

def get_parameters(model):
    return [val.cpu().numpy() for _, val in model.state_dict().items()]

def set_parameters(model, parameters):
    params_dict = zip(model.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.tensor(v) for k, v in params_dict})
    model.load_state_dict(state_dict, strict=True)

print("Testing Fixed Enhanced Hybrid EfficientNet-B0 + MobileViT-S + ESA...")
test_model = EfficientNetB0MobileViT(num_classes=NUM_MAIZE_CLASSES).to(device)
model_size = test_model.get_model_size()
total_params = sum(p.numel() for p in test_model.parameters())

print(f"Fixed Enhanced Hybrid Model Created Successfully!")
print(f"  Total parameters: {total_params:,}")
print(f"  Model size: {model_size:.2f} MB")
print(f"  Tensor dimension issues: RESOLVED")

del test_model
# Out:
# Testing Fixed Enhanced Hybrid EfficientNet-B0 + MobileViT-S + ESA...
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100%|██████████| 20.4M/20.4M [00:00<00:00, 154MB/s]
# Loaded pretrained weights for efficientnet-b0
# EfficientNet-B0 + MobileViT initialized:
#   Total parameters: 4,857,687
# Fixed Enhanced Hybrid Model Created Successfully!
#   Total parameters: 4,857,687
#   Model size: 18.71 MB
#   Tensor dimension issues: RESOLVED

# %%
# Cell 8: Create non-IID data distribution for maize disease federated learning
def create_non_iid_maize_disease_datasets(dataset, num_clients=3):
    """
    Create non-IID data distributions for maize disease detection
    Each client specializes in different types of maize diseases
    """
    from collections import defaultdict

    # Group data by maize disease class
    class_indices = defaultdict(list)
    for idx, (_, label) in enumerate(dataset):
        class_indices[label].append(idx)

    print(f"Original maize disease dataset distribution:")
    for class_idx, indices in class_indices.items():
        print(f"  {MAIZE_CLASS_NAMES[class_idx]}: {len(indices)} samples")

    client_datasets = []

    # Define specialization for each client based on maize disease types
    if NUM_MAIZE_CLASSES >= 5:
        client_specializations = {
            0: {
                "name": "Healthy & Early Disease Specialist",
                "primary_classes": [0, 1],  # Typically healthy and early symptoms
                "ratio": 0.7,
                "description": "Specializes in healthy maize and early disease detection"
            },
            1: {
                "name": "Fungal Disease Specialist",
                "primary_classes": [2, 3],  # Fungal diseases like rust, blight
                "ratio": 0.7,
                "description": "Specializes in fungal maize diseases"
            },
            2: {
                "name": "Advanced Disease Specialist",
                "primary_classes": [4] if NUM_MAIZE_CLASSES > 4 else [1, 2],
                "ratio": 0.6,
                "description": "Specializes in complex and advanced maize diseases"
            }
        }
    else:
        # Fallback for datasets with fewer classes
        client_specializations = {
            0: {"name": "Primary Specialist", "primary_classes": [0], "ratio": 0.7},
            1: {"name": "Secondary Specialist", "primary_classes": [1], "ratio": 0.7},
            2: {"name": "Tertiary Specialist", "primary_classes": [2] if NUM_MAIZE_CLASSES > 2 else [0, 1], "ratio": 0.6}
        }

    for client_id in range(num_clients):
        client_indices = []
        specialization = client_specializations.get(client_id, {"primary_classes": [client_id % NUM_MAIZE_CLASSES], "ratio": 0.6})
        primary_classes = specialization["primary_classes"]
        specialty_ratio = specialization["ratio"]

        print(f"\nClient {client_id} - {specialization.get('name', f'Client {client_id}')}:")
        if 'description' in specialization:
            print(f"  Description: {specialization['description']}")
        print(f"  Primary maize diseases: {[MAIZE_CLASS_NAMES[c] for c in primary_classes if c < NUM_MAIZE_CLASSES]}")

        # Assign primary maize disease class samples
        for class_idx in primary_classes:
            if class_idx < len(class_indices):
                indices = class_indices[class_idx].copy()
                num_samples = int(len(indices) * specialty_ratio)
                client_indices.extend(indices[:num_samples])
                class_indices[class_idx] = indices[num_samples:]
                print(f"    {MAIZE_CLASS_NAMES[class_idx]}: {num_samples} samples (primary)")

        # Add diversity samples from all other maize disease classes
        for class_idx in range(NUM_MAIZE_CLASSES):
            if class_idx not in primary_classes and class_indices[class_idx]:
                indices = class_indices[class_idx]
                # Ensure representation of all maize diseases for robustness
                min_samples = max(5, len(indices) // (num_clients * 3))
                num_samples = min(min_samples, len(indices) // 2)
                client_indices.extend(indices[:num_samples])
                class_indices[class_idx] = indices[num_samples:]
                print(f"    {MAIZE_CLASS_NAMES[class_idx]}: {num_samples} samples (diversity)")

        client_datasets.append(Subset(dataset, client_indices))

    # Distribute remaining maize disease samples
    remaining_indices = []
    for indices in class_indices.values():
        remaining_indices.extend(indices)

    if remaining_indices:
        print(f"\nDistributing {len(remaining_indices)} remaining maize disease samples...")
        for i, idx in enumerate(remaining_indices):
            client_id = i % num_clients
            client_datasets[client_id].indices.append(idx)

    # Print final maize disease distribution
    print(f"\nFINAL MAIZE DISEASE CLIENT DISTRIBUTIONS:")
    print(f"{'='*70}")

    for i, client_dataset in enumerate(client_datasets):
        class_counts = defaultdict(int)
        for idx in client_dataset.indices:
            _, label = dataset[idx]
            class_counts[label] += 1

        print(f"\nClient {i} - Maize Disease Distribution:")
        print(f"  Total samples: {len(client_dataset)}")
        for class_idx, count in sorted(class_counts.items()):
            percentage = (count / len(client_dataset)) * 100
            print(f"    {MAIZE_CLASS_NAMES[class_idx]}: {count} samples ({percentage:.1f}%)")

    return client_datasets

# Create non-IID maize disease client datasets
print("Creating non-IID client datasets for maize disease federated learning...")
maize_client_datasets = create_non_iid_maize_disease_datasets(maize_train_dataset, num_clients=3)
# Out:
# Creating non-IID client datasets for maize disease federated learning...
# Original maize disease dataset distribution:
#   fall armyworm: 1140 samples
#   grasshoper: 2575 samples
#   healthy: 830 samples
#   leaf beetle: 3789 samples
#   leaf blight: 4025 samples
#   leaf spot: 3024 samples
#   streak virus: 4043 samples
#
# Client 0 - Healthy & Early Disease Specialist:
#   Description: Specializes in healthy maize and early disease detection
#   Primary maize diseases: ['fall armyworm', 'grasshoper']
#     fall armyworm: 798 samples (primary)
#     grasshoper: 1802 samples (primary)
#     healthy: 92 samples (diversity)
#     leaf beetle: 421 samples (diversity)
#     leaf blight: 447 samples (diversity)
#     leaf spot: 336 samples (diversity)
#     streak virus: 449 samples (diversity)
#
# Client 1 - Fungal Disease Specialist:
#   Description: Specializes in fungal maize diseases
#   Primary maize diseases: ['healthy', 'leaf beetle']
#     healthy: 516 samples (primary)
#     leaf beetle: 2357 samples (primary)
#     fall armyworm: 38 samples (diversity)
#     grasshoper: 85 samples (diversity)
#     leaf blight: 397 samples (diversity)
#     leaf spot: 298 samples (diversity)
#     streak virus: 399 samples (diversity)
#
# Client 2 - Advanced Disease Specialist:
#   Description: Specializes in complex and advanced maize diseases
#   Primary maize diseases: ['leaf blight']
#     leaf blight: 1908 samples (primary)
#     fall armyworm: 33 samples (diversity)
#     grasshoper: 76 samples (diversity)
#     healthy: 24 samples (diversity)
#     leaf beetle: 112 samples (diversity)
#     leaf spot: 265 samples (diversity)
#     streak virus: 355 samples (diversity)
#
# Distributing 8218 remaining maize disease samples...
#
# FINAL MAIZE DISEASE CLIENT DISTRIBUTIONS:
# ======================================================================
#
# Client 0 - Maize Disease Distribution:
#   Total samples: 7085
#     fall armyworm: 889 samples (12.5%)
#     grasshoper: 2006 samples (28.3%)
#     healthy: 158 samples (2.2%)
#     leaf beetle: 720 samples (10.2%)
#     leaf blight: 872 samples (12.3%)
#     leaf spot: 1044 samples (14.7%)
#     streak virus: 1396 samples (19.7%)
#
# Client 1 - Maize Disease Distribution:
#   Total samples: 6829
#     fall armyworm: 128 samples (1.9%)
#     grasshoper: 289 samples (4.2%)
#     healthy: 582 samples (8.5%)
#     leaf beetle: 2657 samples (38.9%)
#     leaf blight: 821 samples (12.0%)
#     leaf spot: 1007 samples (14.7%)
#     streak virus: 1345 samples (19.7%)
#
# Client 2 - Maize Disease Distribution:
#   Total samples: 5512
#     fall armyworm: 123 samples (2.2%)
#     grasshoper: 280 samples (5.1%)
#     healthy: 90 samples (1.6%)
#     leaf beetle: 412 samples (7.5%)
#     leaf blight: 2332 samples (42.3%)
#     leaf spot: 973 samples (17.7%)
#     streak virus: 1302 samples (23.6%)

# %%
from sklearn.model_selection import train_test_split

def stratified_split(dataset, val_ratio=0.2):
    targets = [s[1] for s in dataset.samples]
    indices = np.arange(len(dataset))
    train_idx, val_idx = train_test_split(
        indices, test_size=val_ratio, stratify=targets, random_state=42)
    return Subset(dataset, train_idx), Subset(dataset, val_idx)

def create_maize_client_train_val_splits(client_datasets, val_ratio=0.2):
    client_train_datasets, client_val_datasets = [], []
    print("Creating stratified train/validation splits for each client:")
    for i, client_dataset in enumerate(client_datasets):
        # Get targets for this subset
        indices = client_dataset.indices
        targets = [client_dataset.dataset.samples[idx][1] for idx in indices]
        train_idx, val_idx = train_test_split(
            indices, test_size=val_ratio, stratify=targets, random_state=42)
        client_train_datasets.append(Subset(client_dataset.dataset, train_idx))
        client_val_datasets.append(Subset(client_dataset.dataset, val_idx))
        print(f"  Client {i}: {len(train_idx)} train, {len(val_idx)} val samples")
    return client_train_datasets, client_val_datasets

maize_client_train_datasets, maize_client_val_datasets = create_maize_client_train_val_splits(maize_client_datasets)
print(f"\nMaize disease client dataset preparation completed!")
print(f"Total maize disease clients: {len(maize_client_train_datasets)}")
# Out:
# Creating stratified train/validation splits for each client:
#   Client 0: 5668 train, 1417 val samples
#   Client 1: 5463 train, 1366 val samples
#   Client 2: 4409 train, 1103 val samples
#
# Maize disease client dataset preparation completed!
# Total maize disease clients: 3

# %%
# Compute class weights for maize disease dataset
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Extract labels from your training dataset
train_targets = []
for i in range(len(maize_train_dataset)):
    _, label = maize_train_dataset[i]
    train_targets.append(label)

# Compute balanced class weights
class_weights = compute_class_weight(
    'balanced', 
    classes=np.arange(NUM_MAIZE_CLASSES), 
    y=train_targets
)

# Convert to tensor
class_weights_tensor = torch.FloatTensor(class_weights).to(device)

print(f"Class weights computed: {class_weights}")
print(f"Class weights tensor shape: {class_weights_tensor.shape}")
# Out:
# Class weights computed: [2.43433584 1.07772538 3.34354561 0.73242092 0.68947649 0.91770597
#  0.68640684]
# Class weights tensor shape: torch.Size([7])

# %%
# Cell 10: Enhanced CCMT Client with Adaptive Dynamic Aggregation Support
import torch.optim as optim
from torch.optim.lr_scheduler import LinearLR, StepLR, SequentialLR
from sklearn.metrics import f1_score
import numpy as np

class EnhancedMaizeDiseaseClient(NumPyClient):
    """Enhanced Maize Disease client with adaptive dynamic aggregation support"""

    def __init__(self, client_id: int, trainset: Subset, valset: Subset):
        self.client_id = client_id
        self.trainset = trainset
        self.valset = valset
        
        # Use your hybrid model architecture
        self.model =  EfficientNetB0MobileViT(num_classes=NUM_MAIZE_CLASSES).to(device)
        
        import os
        
        num_cpu = os.cpu_count()
        
        self.trainloader = DataLoader(
            self.trainset,
            batch_size=32,
            shuffle=True,
            pin_memory=True,
            num_workers=min(8, num_cpu // 2),  # Adaptive to system
            persistent_workers=True
        )
        
        self.valloader = DataLoader(
            self.valset,
            batch_size=64,
            shuffle=False,
            pin_memory=True,
            num_workers=min(4, num_cpu // 2)  # Usually smaller for val
        )
        # Balanced loss function
        self.criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
        
        # Optimized optimizer settings
        self.optimizer = optim.AdamW(
            self.model.parameters(),
            lr=0.001,
            weight_decay=0.01,
            betas=(0.9, 0.999),
            eps=1e-8
        )

        # Advanced learning rate scheduling
        warmup_scheduler = LinearLR(
            self.optimizer,
            start_factor=0.1,
            total_iters=2
        )
        
        main_scheduler = StepLR(
            self.optimizer,
            step_size=3,
            gamma=0.7
        )
        
        self.scheduler = SequentialLR(
            self.optimizer,
            schedulers=[warmup_scheduler, main_scheduler],
            milestones=[2]
        )
        
        self.current_round = 0
        
        print(f"Adaptive Maize Disease Client {client_id} initialized with {len(trainset)} training samples")

    def get_parameters(self, config):
        return get_parameters(self.model)

    def fit(self, parameters, config):
        set_parameters(self.model, parameters)
        epochs = config.get("epochs", 2)
        self.current_round = config.get('round_num', self.current_round + 1)
        
        self.model.train()

        # Training loop with gradient clipping
        for epoch in range(epochs):
            for data, target in self.trainloader:
                data, target = data.to(device), target.to(device)
                self.optimizer.zero_grad()
                output = self.model(data)
                loss = self.criterion(output, target)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=1.0)
                self.optimizer.step()
        
        # Step scheduler
        self.scheduler.step()
        current_lr = self.optimizer.param_groups[0]['lr']

        # Comprehensive evaluation for adaptive aggregation
        all_preds, all_targets = [], []
        self.model.eval()
        with torch.no_grad():
            for data, target in self.valloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                preds = output.argmax(1)
                all_preds.extend(preds.cpu().numpy())
                all_targets.extend(target.cpu().numpy())
        
        # Calculate per-class F1 scores for adaptive aggregation
        f1_per_class = f1_score(all_targets, all_preds, average=None, 
                               labels=np.arange(NUM_MAIZE_CLASSES), zero_division=0)
        
        # Overall metrics
        accuracy = np.mean(np.array(all_preds) == np.array(all_targets))
        overall_f1 = f1_score(all_targets, all_preds, average='weighted', zero_division=0)
        
        metrics = {
            "accuracy": accuracy,
            "f1_score": overall_f1,
            "f1_per_class": f1_per_class.tolist(),
            "learning_rate": current_lr
        }
        
        print(f"  Client {self.client_id} Round {self.current_round}: "
              f"{accuracy*100:.1f}% accuracy, F1: {overall_f1:.3f}, LR: {current_lr:.6f}")
        
        return get_parameters(self.model), len(self.trainset), metrics

    def evaluate(self, parameters, config):
        set_parameters(self.model, parameters)
        self.model.eval()
        all_preds, all_targets = [], []
        
        with torch.no_grad():
            for data, target in self.valloader:
                data, target = data.to(device), target.to(device)
                output = self.model(data)
                preds = output.argmax(1)
                all_preds.extend(preds.cpu().numpy())
                all_targets.extend(target.cpu().numpy())
        
        # Calculate comprehensive metrics
        accuracy = np.mean(np.array(all_preds) == np.array(all_targets))
        f1_per_class = f1_score(all_targets, all_preds, average=None, 
                               labels=np.arange(NUM_MAIZE_CLASSES), zero_division=0)
        overall_f1 = f1_score(all_targets, all_preds, average='weighted', zero_division=0)
        
        metrics = {
            "accuracy": accuracy,
            "f1_score": overall_f1,
            "f1_per_class": f1_per_class.tolist()
        }
        
        return np.nan, len(self.valset), metrics

print("Adaptive Maize Disease federated client implementation created!")
# Out:
# Adaptive Maize Disease federated client implementation created!

# %%
# Cell 11: Adaptive Dynamic Weighted Aggregation for Maize Disease Detection
import numpy as np

def adaptive_dynamic_weighted_aggregation(client_metrics, alpha=0.7, low_performance_threshold=0.25):
    """
    Adaptive dynamic weighted aggregation that focuses on any low-performing diseases
    based on F1 scores across all maize disease clients.
    
    Args:
        client_metrics: List of dicts containing f1_per_class and num_samples
        alpha: Weight balance between data size (alpha) and performance (1-alpha)
        low_performance_threshold: Percentile threshold to identify low-performing classes
    
    Returns:
        weights: List of aggregation weights for each client
        aggregation_info: Dict with detailed information about the aggregation
    """
    num_clients = len(client_metrics)
    num_classes = len(client_metrics[0]['f1_per_class'])
    
    # Step 1: Collect F1 scores from all clients
    f1_matrix = np.array([client['f1_per_class'] for client in client_metrics])
    
    # Step 2: Compute global average F1 per class
    global_avg_f1_per_class = np.mean(f1_matrix, axis=0)
    
    # Step 3: Identify low-performing classes dynamically
    threshold_value = np.percentile(global_avg_f1_per_class, low_performance_threshold * 100)
    low_performance_mask = global_avg_f1_per_class <= threshold_value
    low_performance_indices = np.where(low_performance_mask)[0]
    
    print(f"Global F1 scores per maize disease class:")
    for i, f1_score in enumerate(global_avg_f1_per_class):
        status = "🔴 LOW" if i in low_performance_indices else "✅ OK"
        print(f"  {MAIZE_CLASS_NAMES[i]}: {f1_score:.3f} {status}")
    
    print(f"Low performance threshold: F1 <= {threshold_value:.3f}")
    print(f"Low-performing classes: {[MAIZE_CLASS_NAMES[i] for i in low_performance_indices]}")
    
    # Step 4: Compute performance weights for each client
    performance_weights = []
    data_weights = []
    
    sample_sizes = np.array([client['num_samples'] for client in client_metrics])
    total_samples = sample_sizes.sum()
    
    for i, client in enumerate(client_metrics):
        f1_scores = np.array(client['f1_per_class'])
        
        # Data weight (standard FedAvg component)
        data_weight = sample_sizes[i] / total_samples
        data_weights.append(data_weight)
        
        # Performance weight focusing on low-performing classes
        if len(low_performance_indices) > 0:
            # Average F1 score on low-performing classes
            low_perf_f1 = np.mean(f1_scores[low_performance_indices])
            # Overall F1 score
            overall_f1 = np.mean(f1_scores)
            # Combine with emphasis on low-performing classes
            perf_weight = 0.7 * low_perf_f1 + 0.3 * overall_f1
        else:
            # If no low-performing classes identified, use overall F1
            perf_weight = np.mean(f1_scores)
        
        performance_weights.append(perf_weight)
    
    # Step 5: Normalize performance weights
    performance_weights = np.array(performance_weights)
    if performance_weights.max() - performance_weights.min() > 1e-6:
        performance_weights = (performance_weights - performance_weights.min()) / \
                            (performance_weights.max() - performance_weights.min())
    else:
        performance_weights = np.ones_like(performance_weights)
    
    # Step 6: Combine data and performance weights
    data_weights = np.array(data_weights)
    combined_weights = alpha * data_weights + (1 - alpha) * performance_weights
    
    # Step 7: Final normalization
    combined_weights = combined_weights / combined_weights.sum()
    
    # Prepare detailed information
    aggregation_info = {
        'threshold_value': threshold_value,
        'low_performance_indices': low_performance_indices.tolist(),
        'low_performance_classes': [MAIZE_CLASS_NAMES[i] for i in low_performance_indices],
        'global_avg_f1': global_avg_f1_per_class.tolist(),
        'data_weights': data_weights.tolist(),
        'performance_weights': performance_weights.tolist(),
        'combined_weights': combined_weights.tolist(),
        'num_low_performance_classes': len(low_performance_indices),
        'alpha': alpha
    }
    
    return combined_weights.tolist(), aggregation_info

def print_aggregation_summary(info, client_metrics):
    """Print detailed summary of adaptive aggregation"""
    print("\n" + "="*70)
    print("ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY")
    print("="*70)
    
    print(f"Focus Strategy: Bottom {int((1-info['alpha'])*100)}% of classes by F1 score")
    print(f"Data vs Performance Weight Balance: {info['alpha']:.1f} / {1-info['alpha']:.1f}")
    print(f"Low-performing classes targeted: {info['num_low_performance_classes']}")
    
    if info['low_performance_classes']:
        print(f"Targeted diseases: {', '.join(info['low_performance_classes'])}")
    
    print(f"\nClient Weight Distribution:")
    for i, (data_w, perf_w, final_w) in enumerate(zip(
        info['data_weights'], info['performance_weights'], info['combined_weights']
    )):
        print(f"  Client {i}: Data={data_w:.3f}, Perf={perf_w:.3f} → Final={final_w:.3f}")
    
    print("="*70)

# Test the adaptive aggregation function
print("Adaptive Dynamic Weighted Aggregation implementation ready for Maize Disease Detection!")
# Out:
# Adaptive Dynamic Weighted Aggregation implementation ready for Maize Disease Detection!

# %%
# Cell 12: Client function for maize disease simulation
def maize_client_fn(cid: str):
    """Create a Flower client for maize disease detection"""

    # Get client ID
    client_id = int(cid)

    # Get the client's maize disease dataset
    trainset = maize_client_train_datasets[client_id]
    valset = maize_client_val_datasets[client_id]

    # Create and return maize disease client
    return EnhancedMaizeDiseaseClient(client_id, trainset, valset)

print("Maize disease client function for simulation created!")
# Out:
# Maize disease client function for simulation created!

# %%
# Cell 12: Complete Maize Disease Federated Learning with Adaptive Aggregation
import time
import gc

def run_adaptive_maize_federated_learning():
    """Complete maize disease federated learning with adaptive dynamic weighted aggregation"""

    # Force GPU usage
    if not torch.cuda.is_available():
        raise RuntimeError("GPU not available!")

    print(f"Running Adaptive FL on Maize Disease dataset using: {torch.cuda.get_device_name(0)}")

    # Initialize global model
    global_model =  EfficientNetB0MobileViT(num_classes=NUM_MAIZE_CLASSES)
    global_model = global_model.to(device)

    print("="*80)
    print("ADAPTIVE FEDERATED LEARNING FOR MAIZE DISEASE DETECTION")
    print("="*80)

    # Initialize global model parameters
    global_parameters = get_parameters(global_model)

    # Create adaptive clients
    clients = []
    for client_id in range(len(maize_client_train_datasets)):
        client = EnhancedMaizeDiseaseClient(
            client_id,
            maize_client_train_datasets[client_id],
            maize_client_val_datasets[client_id]
        )
        clients.append(client)

    # Training configuration
    num_rounds = 36
    local_epochs = 1

    print(f"Adaptive Maize Disease Federated Learning Configuration:")
    print(f"  Model: Hybrid EfficientNet-B0 + MobileViT + CBAM + ESA")
    print(f"  Aggregation: Adaptive Dynamic Weighted Aggregation")
    print(f"  Training rounds: {num_rounds}")
    print(f"  Local epochs per round: {local_epochs}")
    print(f"  Number of farm clients: {len(clients)}")
    print(f"  Disease classes: {NUM_MAIZE_CLASSES} ({', '.join(MAIZE_CLASS_NAMES)})")

    round_accuracies = []
    round_losses = []
    best_accuracy = 0.0

    # Adaptive federated learning training loop
    for round_num in range(1, num_rounds + 1):
        round_start_time = time.time()

        print(f"\n{'='*60}")
        print(f"ROUND {round_num}/{num_rounds}")
        print(f"{'='*60}")

        client_results = []
        client_metrics = []
        total_samples = 0

        # Client training phase
        for client in clients:
            print(f"Training Maize Disease Client {client.client_id}...")
            updated_params, num_samples, metrics = client.fit(
                global_parameters,
                {"epochs": local_epochs, "round_num": round_num}
            )
            
            client_results.append((updated_params, num_samples, metrics))
            total_samples += num_samples
            
            # Collect metrics for adaptive aggregation
            client_metrics.append({
                'f1_per_class': metrics['f1_per_class'],
                'num_samples': num_samples,
                'accuracy': metrics['accuracy'],
                'f1_score': metrics['f1_score']
            })

        # Adaptive Dynamic Weighted Aggregation
        print(f"\nPerforming Adaptive Dynamic Weighted Aggregation...")
        
        weights, aggregation_info = adaptive_dynamic_weighted_aggregation(
            client_metrics, 
            alpha=0.7,  # 70% data weight, 30% performance weight
            low_performance_threshold=0.25  # Focus on bottom 25% classes
        )
        
        # Print detailed aggregation summary
        print_aggregation_summary(aggregation_info, client_metrics)

        # Aggregate parameters using adaptive weights
        aggregated_params = None
        for i, (params, num_samples, metrics) in enumerate(client_results):
            weighted_params = [layer * weights[i] for layer in params]
            
            if aggregated_params is None:
                aggregated_params = weighted_params
            else:
                aggregated_params = [
                    layer1 + layer2 for layer1, layer2 in zip(aggregated_params, weighted_params)
                ]

        global_parameters = aggregated_params

        # Global evaluation on maize disease test set
        set_parameters(global_model, global_parameters)
        global_model.eval()

        correct = 0
        total = 0
        total_loss = 0.0
        all_preds = []
        all_targets = []
        criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)

        with torch.no_grad():
            for data, target in maize_test_loader:
                data, target = data.to(device), target.to(device)
                output = global_model(data)
                loss = criterion(output, target)
                total_loss += loss.item()
                _, predicted = output.max(1)
                total += target.size(0)
                correct += predicted.eq(target).sum().item()
                
                all_preds.extend(predicted.cpu().numpy())
                all_targets.extend(target.cpu().numpy())

        accuracy = correct / total
        avg_loss = total_loss / len(maize_test_loader)
        
        # Calculate per-class F1 scores for global model
        global_f1_per_class = f1_score(all_targets, all_preds, average=None, 
                                      labels=np.arange(NUM_MAIZE_CLASSES), zero_division=0)
        global_f1_weighted = f1_score(all_targets, all_preds, average='weighted', zero_division=0)

        round_accuracies.append(accuracy)
        round_losses.append(avg_loss)

        # Track best model
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            torch.save(global_model.state_dict(), 'best_maize_adaptive_model.pth')
            print(f"  🎯 New best accuracy! Model saved.")

        round_time = time.time() - round_start_time

        print(f"\nRound {round_num} Global Results:")
        print(f"  Overall Accuracy: {accuracy*100:.2f}%")
        print(f"  Weighted F1 Score: {global_f1_weighted:.4f}")
        print(f"  Global Loss: {avg_loss:.4f}")
        print(f"  Round Time: {round_time:.1f}s")
        
        # Show per-class performance
        print(f"  Per-class F1 scores:")
        for i, f1 in enumerate(global_f1_per_class):
            status = "bad" if i in aggregation_info['low_performance_indices'] else "good"
            print(f"    {MAIZE_CLASS_NAMES[i]}: {f1:.3f} {status}")

        # Memory cleanup
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        gc.collect()

        # Early stopping check
        if accuracy > 0.95:
            print(f"\n🎉 Excellent accuracy achieved! Stopping at round {round_num}")
            break

    # Final summary
    print(f"\n{'='*80}")
    print(f"ADAPTIVE MAIZE DISEASE FEDERATED LEARNING COMPLETED")
    print(f"{'='*80}")
    print(f"Final Accuracy: {round_accuracies[-1]*100:.2f}%")
    print(f"Best Accuracy: {max(round_accuracies)*100:.2f}%")
    print(f"Improvement from adaptive aggregation: Focus on challenging diseases")

    model_size_mb = global_model.get_model_size()
    print(f"Model size: {model_size_mb:.2f} MB (Edge ready: {'Yes' if model_size_mb < 50 else 'No'})")

    return global_model, round_accuracies, round_losses, aggregation_info

# FIXED: Consistent naming
print("Starting Federated Learning for Maize Disease Detection with Adaptive Aggregation...")
final_model, accuracies, losses, final_aggregation_info = run_adaptive_maize_federated_learning()
# Out:
# Starting Federated Learning for Maize Disease Detection with Adaptive Aggregation...
# Running Adaptive FL on Maize Disease dataset using: Tesla T4
# Loaded pretrained weights for efficientnet-b0
# EfficientNet-B0 + MobileViT initialized:
#   Total parameters: 4,857,687
# ================================================================================
# ADAPTIVE FEDERATED LEARNING FOR MAIZE DISEASE DETECTION
# ================================================================================
# Loaded pretrained weights for efficientnet-b0
# EfficientNet-B0 + MobileViT initialized:
#   Total parameters: 4,857,687
# Adaptive Maize Disease Client 0 initialized with 5668 training samples
# Loaded pretrained weights for efficientnet-b0
# EfficientNet-B0 + MobileViT initialized:
#   Total parameters: 4,857,687
# Adaptive Maize Disease Client 1 initialized with 5463 training samples
# Loaded pretrained weights for efficientnet-b0
# EfficientNet-B0 + MobileViT initialized:
#   Total parameters: 4,857,687
# Adaptive Maize Disease Client 2 initialized with 4409 training samples
# Adaptive Maize Disease Federated Learning Configuration:
#   Model: Hybrid EfficientNet-B0 + MobileViT + CBAM + ESA
#   Aggregation: Adaptive Dynamic Weighted Aggregation
#   Training rounds: 36
#   Local epochs per round: 1
#   Number of farm clients: 3
#   Disease classes: 7 (fall armyworm, grasshoper, healthy, leaf beetle, leaf blight, leaf spot, streak virus)
#
# ============================================================
# ROUND 1/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 1: 80.9% accuracy, F1: 0.804, LR: 0.000550
# Training Maize Disease Client 1...
#   Client 1 Round 1: 78.2% accuracy, F1: 0.773, LR: 0.000550
# Training Maize Disease Client 2...
#   Client 2 Round 1: 72.4% accuracy, F1: 0.724, LR: 0.000550
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.696 ✅ OK
#   grasshoper: 0.844 ✅ OK
#   healthy: 0.623 ✅ OK
#   leaf beetle: 0.914 ✅ OK
#   leaf blight: 0.564 🔴 LOW
#   leaf spot: 0.579 🔴 LOW
#   streak virus: 0.793 ✅ OK
# Low performance threshold: F1 <= 0.601
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.667 → Final=0.379
#   Client 1: Data=0.352, Perf=0.000 → Final=0.205
#   Client 2: Data=0.284, Perf=1.000 → Final=0.415
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 1 Global Results:
#   Overall Accuracy: 72.14%
#   Weighted F1 Score: 0.7182
#   Global Loss: 0.7859
#   Round Time: 314.2s
#   Per-class F1 scores:
#     fall armyworm: 0.751 good
#     grasshoper: 0.799 good
#     healthy: 0.587 good
#     leaf beetle: 0.906 good
#     leaf blight: 0.642 bad
#     leaf spot: 0.577 bad
#     streak virus: 0.780 good
#
# ============================================================
# ROUND 2/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 2: 76.6% accuracy, F1: 0.775, LR: 0.001000
# Training Maize Disease Client 1...
#   Client 1 Round 2: 83.0% accuracy, F1: 0.825, LR: 0.001000
# Training Maize Disease Client 2...
#   Client 2 Round 2: 70.7% accuracy, F1: 0.724, LR: 0.001000
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.683 ✅ OK
#   grasshoper: 0.824 ✅ OK
#   healthy: 0.632 🔴 LOW
#   leaf beetle: 0.848 ✅ OK
#   leaf blight: 0.690 ✅ OK
#   leaf spot: 0.616 🔴 LOW
#   streak virus: 0.805 ✅ OK
# Low performance threshold: F1 <= 0.658
# Low-performing classes: ['healthy', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: healthy, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.612 → Final=0.371
#   Client 1: Data=0.352, Perf=1.000 → Final=0.461
#   Client 2: Data=0.284, Perf=0.000 → Final=0.168
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 2 Global Results:
#   Overall Accuracy: 80.00%
#   Weighted F1 Score: 0.7993
#   Global Loss: 0.5195
#   Round Time: 292.0s
#   Per-class F1 scores:
#     fall armyworm: 0.862 good
#     grasshoper: 0.871 good
#     healthy: 0.712 bad
#     leaf beetle: 0.935 good
#     leaf blight: 0.697 good
#     leaf spot: 0.711 bad
#     streak virus: 0.855 good
#
# ============================================================
# ROUND 3/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 3: 74.9% accuracy, F1: 0.736, LR: 0.001000
# Training Maize Disease Client 1...
#   Client 1 Round 3: 79.8% accuracy, F1: 0.797, LR: 0.001000
# Training Maize Disease Client 2...
#   Client 2 Round 3: 68.9% accuracy, F1: 0.698, LR: 0.001000
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.651 ✅ OK
#   grasshoper: 0.808 ✅ OK
#   healthy: 0.574 ✅ OK
#   leaf beetle: 0.860 ✅ OK
#   leaf blight: 0.542 🔴 LOW
#   leaf spot: 0.552 🔴 LOW
#   streak virus: 0.791 ✅ OK
# Low performance threshold: F1 <= 0.563
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.000 → Final=0.202
#   Client 1: Data=0.352, Perf=1.000 → Final=0.431
#   Client 2: Data=0.284, Perf=0.886 → Final=0.367
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 3 Global Results:
#   Overall Accuracy: 82.20%
#   Weighted F1 Score: 0.8229
#   Global Loss: 0.4693
#   Round Time: 295.5s
#   Per-class F1 scores:
#     fall armyworm: 0.864 good
#     grasshoper: 0.926 good
#     healthy: 0.784 good
#     leaf beetle: 0.954 good
#     leaf blight: 0.748 bad
#     leaf spot: 0.734 bad
#     streak virus: 0.839 good
#
# ============================================================
# ROUND 4/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 4: 80.2% accuracy, F1: 0.806, LR: 0.001000
# Training Maize Disease Client 1...
#   Client 1 Round 4: 77.7% accuracy, F1: 0.772, LR: 0.001000
# Training Maize Disease Client 2...
#   Client 2 Round 4: 74.3% accuracy, F1: 0.748, LR: 0.001000
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.562 🔴 LOW
#   grasshoper: 0.845 ✅ OK
#   healthy: 0.528 🔴 LOW
#   leaf beetle: 0.862 ✅ OK
#   leaf blight: 0.712 ✅ OK
#   leaf spot: 0.578 ✅ OK
#   streak virus: 0.800 ✅ OK
# Low performance threshold: F1 <= 0.570
# Low-performing classes: ['fall armyworm', 'healthy']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: fall armyworm, healthy
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.488
#   Client 1: Data=0.352, Perf=0.459 → Final=0.337
#   Client 2: Data=0.284, Perf=0.000 → Final=0.175
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 4 Global Results:
#   Overall Accuracy: 82.97%
#   Weighted F1 Score: 0.8305
#   Global Loss: 0.4663
#   Round Time: 289.7s
#   Per-class F1 scores:
#     fall armyworm: 0.878 bad
#     grasshoper: 0.935 good
#     healthy: 0.774 bad
#     leaf beetle: 0.957 good
#     leaf blight: 0.765 good
#     leaf spot: 0.721 good
#     streak virus: 0.869 good
#
# ============================================================
# ROUND 5/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 5: 83.1% accuracy, F1: 0.829, LR: 0.000700
# Training Maize Disease Client 1...
#   Client 1 Round 5: 81.0% accuracy, F1: 0.813, LR: 0.000700
# Training Maize Disease Client 2...
#   Client 2 Round 5: 76.2% accuracy, F1: 0.768, LR: 0.000700
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.667 🔴 LOW
#   grasshoper: 0.854 ✅ OK
#   healthy: 0.688 ✅ OK
#   leaf beetle: 0.922 ✅ OK
#   leaf blight: 0.706 ✅ OK
#   leaf spot: 0.657 🔴 LOW
#   streak virus: 0.832 ✅ OK
# Low performance threshold: F1 <= 0.678
# Low-performing classes: ['fall armyworm', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: fall armyworm, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.508
#   Client 1: Data=0.352, Perf=0.000 → Final=0.225
#   Client 2: Data=0.284, Perf=0.309 → Final=0.267
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 5 Global Results:
#   Overall Accuracy: 85.09%
#   Weighted F1 Score: 0.8508
#   Global Loss: 0.3917
#   Round Time: 290.4s
#   Per-class F1 scores:
#     fall armyworm: 0.928 bad
#     grasshoper: 0.927 good
#     healthy: 0.813 good
#     leaf beetle: 0.953 good
#     leaf blight: 0.788 good
#     leaf spot: 0.766 bad
#     streak virus: 0.880 good
#
# ============================================================
# ROUND 6/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 6: 85.7% accuracy, F1: 0.856, LR: 0.000700
# Training Maize Disease Client 1...
#   Client 1 Round 6: 86.5% accuracy, F1: 0.860, LR: 0.000700
# Training Maize Disease Client 2...
#   Client 2 Round 6: 83.0% accuracy, F1: 0.827, LR: 0.000700
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.883 ✅ OK
#   grasshoper: 0.912 ✅ OK
#   healthy: 0.779 ✅ OK
#   leaf beetle: 0.937 ✅ OK
#   leaf blight: 0.768 🔴 LOW
#   leaf spot: 0.676 🔴 LOW
#   streak virus: 0.866 ✅ OK
# Low performance threshold: F1 <= 0.773
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.372 → Final=0.330
#   Client 1: Data=0.352, Perf=0.000 → Final=0.221
#   Client 2: Data=0.284, Perf=1.000 → Final=0.448
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 6 Global Results:
#   Overall Accuracy: 86.65%
#   Weighted F1 Score: 0.8653
#   Global Loss: 0.3459
#   Round Time: 289.2s
#   Per-class F1 scores:
#     fall armyworm: 0.948 good
#     grasshoper: 0.963 good
#     healthy: 0.840 good
#     leaf beetle: 0.967 good
#     leaf blight: 0.807 bad
#     leaf spot: 0.760 bad
#     streak virus: 0.901 good
#
# ============================================================
# ROUND 7/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 7: 85.6% accuracy, F1: 0.858, LR: 0.000700
# Training Maize Disease Client 1...
#   Client 1 Round 7: 80.4% accuracy, F1: 0.803, LR: 0.000700
# Training Maize Disease Client 2...
#   Client 2 Round 7: 84.0% accuracy, F1: 0.840, LR: 0.000700
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.840 ✅ OK
#   grasshoper: 0.946 ✅ OK
#   healthy: 0.738 🔴 LOW
#   leaf beetle: 0.937 ✅ OK
#   leaf blight: 0.749 ✅ OK
#   leaf spot: 0.663 🔴 LOW
#   streak virus: 0.837 ✅ OK
# Low performance threshold: F1 <= 0.743
# Low-performing classes: ['healthy', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: healthy, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.439 → Final=0.342
#   Client 1: Data=0.352, Perf=0.000 → Final=0.217
#   Client 2: Data=0.284, Perf=1.000 → Final=0.441
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 7 Global Results:
#   Overall Accuracy: 87.10%
#   Weighted F1 Score: 0.8706
#   Global Loss: 0.3312
#   Round Time: 288.5s
#   Per-class F1 scores:
#     fall armyworm: 0.959 good
#     grasshoper: 0.960 good
#     healthy: 0.841 bad
#     leaf beetle: 0.968 good
#     leaf blight: 0.803 good
#     leaf spot: 0.778 bad
#     streak virus: 0.907 good
#
# ============================================================
# ROUND 8/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 8: 87.6% accuracy, F1: 0.877, LR: 0.000490
# Training Maize Disease Client 1...
#   Client 1 Round 8: 88.1% accuracy, F1: 0.878, LR: 0.000490
# Training Maize Disease Client 2...
#   Client 2 Round 8: 83.7% accuracy, F1: 0.838, LR: 0.000490
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.905 ✅ OK
#   grasshoper: 0.930 ✅ OK
#   healthy: 0.770 🔴 LOW
#   leaf beetle: 0.947 ✅ OK
#   leaf blight: 0.782 ✅ OK
#   leaf spot: 0.721 🔴 LOW
#   streak virus: 0.885 ✅ OK
# Low performance threshold: F1 <= 0.776
# Low-performing classes: ['healthy', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: healthy, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.268 → Final=0.311
#   Client 1: Data=0.352, Perf=1.000 → Final=0.505
#   Client 2: Data=0.284, Perf=0.000 → Final=0.184
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 8 Global Results:
#   Overall Accuracy: 87.45%
#   Weighted F1 Score: 0.8735
#   Global Loss: 0.3199
#   Round Time: 287.9s
#   Per-class F1 scores:
#     fall armyworm: 0.973 good
#     grasshoper: 0.975 good
#     healthy: 0.833 bad
#     leaf beetle: 0.980 good
#     leaf blight: 0.798 good
#     leaf spot: 0.784 bad
#     streak virus: 0.900 good
#
# ============================================================
# ROUND 9/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 9: 90.5% accuracy, F1: 0.904, LR: 0.000490
# Training Maize Disease Client 1...
#   Client 1 Round 9: 87.6% accuracy, F1: 0.874, LR: 0.000490
# Training Maize Disease Client 2...
#   Client 2 Round 9: 86.2% accuracy, F1: 0.864, LR: 0.000490
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.924 ✅ OK
#   grasshoper: 0.957 ✅ OK
#   healthy: 0.838 ✅ OK
#   leaf beetle: 0.963 ✅ OK
#   leaf blight: 0.806 🔴 LOW
#   leaf spot: 0.745 🔴 LOW
#   streak virus: 0.894 ✅ OK
# Low performance threshold: F1 <= 0.822
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.956 → Final=0.421
#   Client 1: Data=0.352, Perf=0.000 → Final=0.191
#   Client 2: Data=0.284, Perf=1.000 → Final=0.387
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 9 Global Results:
#   Overall Accuracy: 88.74%
#   Weighted F1 Score: 0.8865
#   Global Loss: 0.2927
#   Round Time: 289.4s
#   Per-class F1 scores:
#     fall armyworm: 0.974 good
#     grasshoper: 0.969 good
#     healthy: 0.871 good
#     leaf beetle: 0.978 good
#     leaf blight: 0.827 bad
#     leaf spot: 0.798 bad
#     streak virus: 0.915 good
#
# ============================================================
# ROUND 10/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 10: 91.0% accuracy, F1: 0.910, LR: 0.000490
# Training Maize Disease Client 1...
#   Client 1 Round 10: 87.8% accuracy, F1: 0.878, LR: 0.000490
# Training Maize Disease Client 2...
#   Client 2 Round 10: 85.5% accuracy, F1: 0.852, LR: 0.000490
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.931 ✅ OK
#   grasshoper: 0.950 ✅ OK
#   healthy: 0.756 🔴 LOW
#   leaf beetle: 0.968 ✅ OK
#   leaf blight: 0.814 ✅ OK
#   leaf spot: 0.743 🔴 LOW
#   streak virus: 0.898 ✅ OK
# Low performance threshold: F1 <= 0.785
# Low-performing classes: ['healthy', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: healthy, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.480
#   Client 1: Data=0.352, Perf=0.523 → Final=0.348
#   Client 2: Data=0.284, Perf=0.000 → Final=0.172
# ======================================================================
#
# Round 10 Global Results:
#   Overall Accuracy: 88.62%
#   Weighted F1 Score: 0.8853
#   Global Loss: 0.3063
#   Round Time: 296.5s
#   Per-class F1 scores:
#     fall armyworm: 0.982 good
#     grasshoper: 0.981 good
#     healthy: 0.827 bad
#     leaf beetle: 0.987 good
#     leaf blight: 0.815 good
#     leaf spot: 0.797 bad
#     streak virus: 0.915 good
#
# ============================================================
# ROUND 11/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 11: 90.6% accuracy, F1: 0.906, LR: 0.000343
# Training Maize Disease Client 1...
#   Client 1 Round 11: 89.6% accuracy, F1: 0.894, LR: 0.000343
# Training Maize Disease Client 2...
#   Client 2 Round 11: 85.1% accuracy, F1: 0.857, LR: 0.000343
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.926 ✅ OK
#   grasshoper: 0.965 ✅ OK
#   healthy: 0.845 ✅ OK
#   leaf beetle: 0.972 ✅ OK
#   leaf blight: 0.795 🔴 LOW
#   leaf spot: 0.743 🔴 LOW
#   streak virus: 0.919 ✅ OK
# Low performance threshold: F1 <= 0.820
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.729 → Final=0.389
#   Client 1: Data=0.352, Perf=0.000 → Final=0.202
#   Client 2: Data=0.284, Perf=1.000 → Final=0.409
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 11 Global Results:
#   Overall Accuracy: 90.01%
#   Weighted F1 Score: 0.8997
#   Global Loss: 0.2564
#   Round Time: 288.1s
#   Per-class F1 scores:
#     fall armyworm: 0.981 good
#     grasshoper: 0.984 good
#     healthy: 0.875 good
#     leaf beetle: 0.986 good
#     leaf blight: 0.823 bad
#     leaf spot: 0.829 bad
#     streak virus: 0.931 good
#
# ============================================================
# ROUND 12/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 12: 93.3% accuracy, F1: 0.932, LR: 0.000343
# Training Maize Disease Client 1...
#   Client 1 Round 12: 91.1% accuracy, F1: 0.911, LR: 0.000343
# Training Maize Disease Client 2...
#   Client 2 Round 12: 88.4% accuracy, F1: 0.885, LR: 0.000343
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.958 ✅ OK
#   grasshoper: 0.972 ✅ OK
#   healthy: 0.870 ✅ OK
#   leaf beetle: 0.984 ✅ OK
#   leaf blight: 0.834 🔴 LOW
#   leaf spot: 0.795 🔴 LOW
#   streak virus: 0.928 ✅ OK
# Low performance threshold: F1 <= 0.852
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.484
#   Client 1: Data=0.352, Perf=0.000 → Final=0.214
#   Client 2: Data=0.284, Perf=0.494 → Final=0.302
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 12 Global Results:
#   Overall Accuracy: 90.36%
#   Weighted F1 Score: 0.9028
#   Global Loss: 0.2494
#   Round Time: 295.4s
#   Per-class F1 scores:
#     fall armyworm: 0.979 good
#     grasshoper: 0.983 good
#     healthy: 0.891 good
#     leaf beetle: 0.986 good
#     leaf blight: 0.834 bad
#     leaf spot: 0.832 bad
#     streak virus: 0.931 good
#
# ============================================================
# ROUND 13/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 13: 92.5% accuracy, F1: 0.924, LR: 0.000343
# Training Maize Disease Client 1...
#   Client 1 Round 13: 91.6% accuracy, F1: 0.915, LR: 0.000343
# Training Maize Disease Client 2...
#   Client 2 Round 13: 87.0% accuracy, F1: 0.872, LR: 0.000343
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.938 ✅ OK
#   grasshoper: 0.974 ✅ OK
#   healthy: 0.848 ✅ OK
#   leaf beetle: 0.970 ✅ OK
#   leaf blight: 0.827 🔴 LOW
#   leaf spot: 0.786 🔴 LOW
#   streak virus: 0.938 ✅ OK
# Low performance threshold: F1 <= 0.837
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.530
#   Client 1: Data=0.352, Perf=0.160 → Final=0.281
#   Client 2: Data=0.284, Perf=0.000 → Final=0.190
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 13 Global Results:
#   Overall Accuracy: 90.56%
#   Weighted F1 Score: 0.9048
#   Global Loss: 0.2519
#   Round Time: 297.2s
#   Per-class F1 scores:
#     fall armyworm: 0.984 good
#     grasshoper: 0.982 good
#     healthy: 0.878 good
#     leaf beetle: 0.987 good
#     leaf blight: 0.832 bad
#     leaf spot: 0.839 bad
#     streak virus: 0.934 good
#
# ============================================================
# ROUND 14/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 14: 91.3% accuracy, F1: 0.915, LR: 0.000240
# Training Maize Disease Client 1...
#   Client 1 Round 14: 91.9% accuracy, F1: 0.918, LR: 0.000240
# Training Maize Disease Client 2...
#   Client 2 Round 14: 87.9% accuracy, F1: 0.881, LR: 0.000240
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.938 ✅ OK
#   grasshoper: 0.966 ✅ OK
#   healthy: 0.756 🔴 LOW
#   leaf beetle: 0.974 ✅ OK
#   leaf blight: 0.829 ✅ OK
#   leaf spot: 0.782 🔴 LOW
#   streak virus: 0.937 ✅ OK
# Low performance threshold: F1 <= 0.806
# Low-performing classes: ['healthy', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: healthy, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.000 → Final=0.253
#   Client 1: Data=0.352, Perf=1.000 → Final=0.541
#   Client 2: Data=0.284, Perf=0.033 → Final=0.207
# ======================================================================
#
# Round 14 Global Results:
#   Overall Accuracy: 90.50%
#   Weighted F1 Score: 0.9042
#   Global Loss: 0.2521
#   Round Time: 297.1s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.987 good
#     healthy: 0.877 bad
#     leaf beetle: 0.988 good
#     leaf blight: 0.825 good
#     leaf spot: 0.840 bad
#     streak virus: 0.933 good
#
# ============================================================
# ROUND 15/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 15: 93.5% accuracy, F1: 0.935, LR: 0.000240
# Training Maize Disease Client 1...
#   Client 1 Round 15: 93.0% accuracy, F1: 0.929, LR: 0.000240
# Training Maize Disease Client 2...
#   Client 2 Round 15: 88.6% accuracy, F1: 0.887, LR: 0.000240
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.953 ✅ OK
#   grasshoper: 0.972 ✅ OK
#   healthy: 0.863 ✅ OK
#   leaf beetle: 0.984 ✅ OK
#   leaf blight: 0.853 🔴 LOW
#   leaf spot: 0.815 🔴 LOW
#   streak virus: 0.945 ✅ OK
# Low performance threshold: F1 <= 0.858
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.534
#   Client 1: Data=0.352, Perf=0.132 → Final=0.275
#   Client 2: Data=0.284, Perf=0.000 → Final=0.191
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 15 Global Results:
#   Overall Accuracy: 91.16%
#   Weighted F1 Score: 0.9109
#   Global Loss: 0.2401
#   Round Time: 301.0s
#   Per-class F1 scores:
#     fall armyworm: 0.984 good
#     grasshoper: 0.988 good
#     healthy: 0.895 good
#     leaf beetle: 0.992 good
#     leaf blight: 0.845 bad
#     leaf spot: 0.844 bad
#     streak virus: 0.936 good
#
# ============================================================
# ROUND 16/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 16: 93.2% accuracy, F1: 0.932, LR: 0.000240
# Training Maize Disease Client 1...
#   Client 1 Round 16: 92.3% accuracy, F1: 0.922, LR: 0.000240
# Training Maize Disease Client 2...
#   Client 2 Round 16: 89.0% accuracy, F1: 0.890, LR: 0.000240
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.967 ✅ OK
#   grasshoper: 0.971 ✅ OK
#   healthy: 0.851 🔴 LOW
#   leaf beetle: 0.983 ✅ OK
#   leaf blight: 0.856 ✅ OK
#   leaf spot: 0.806 🔴 LOW
#   streak virus: 0.933 ✅ OK
# Low performance threshold: F1 <= 0.854
# Low-performing classes: ['healthy', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: healthy, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.669 → Final=0.380
#   Client 1: Data=0.352, Perf=1.000 → Final=0.455
#   Client 2: Data=0.284, Perf=0.000 → Final=0.165
# ======================================================================
#
# Round 16 Global Results:
#   Overall Accuracy: 90.79%
#   Weighted F1 Score: 0.9069
#   Global Loss: 0.2505
#   Round Time: 294.7s
#   Per-class F1 scores:
#     fall armyworm: 0.988 good
#     grasshoper: 0.985 good
#     healthy: 0.889 bad
#     leaf beetle: 0.992 good
#     leaf blight: 0.833 good
#     leaf spot: 0.840 bad
#     streak virus: 0.934 good
#
# ============================================================
# ROUND 17/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 17: 94.1% accuracy, F1: 0.941, LR: 0.000168
# Training Maize Disease Client 1...
#   Client 1 Round 17: 92.9% accuracy, F1: 0.928, LR: 0.000168
# Training Maize Disease Client 2...
#   Client 2 Round 17: 89.2% accuracy, F1: 0.891, LR: 0.000168
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.965 ✅ OK
#   grasshoper: 0.979 ✅ OK
#   healthy: 0.884 ✅ OK
#   leaf beetle: 0.983 ✅ OK
#   leaf blight: 0.857 🔴 LOW
#   leaf spot: 0.811 🔴 LOW
#   streak virus: 0.942 ✅ OK
# Low performance threshold: F1 <= 0.871
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.553
#   Client 1: Data=0.352, Perf=0.017 → Final=0.250
#   Client 2: Data=0.284, Perf=0.000 → Final=0.198
# ======================================================================
#
# Round 17 Global Results:
#   Overall Accuracy: 90.89%
#   Weighted F1 Score: 0.9079
#   Global Loss: 0.2590
#   Round Time: 293.3s
#   Per-class F1 scores:
#     fall armyworm: 0.993 good
#     grasshoper: 0.983 good
#     healthy: 0.899 good
#     leaf beetle: 0.992 good
#     leaf blight: 0.840 bad
#     leaf spot: 0.840 bad
#     streak virus: 0.929 good
#
# ============================================================
# ROUND 18/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 18: 94.1% accuracy, F1: 0.941, LR: 0.000168
# Training Maize Disease Client 1...
#   Client 1 Round 18: 92.7% accuracy, F1: 0.925, LR: 0.000168
# Training Maize Disease Client 2...
#   Client 2 Round 18: 90.1% accuracy, F1: 0.902, LR: 0.000168
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.952 ✅ OK
#   grasshoper: 0.978 ✅ OK
#   healthy: 0.880 ✅ OK
#   leaf beetle: 0.980 ✅ OK
#   leaf blight: 0.852 🔴 LOW
#   leaf spot: 0.822 🔴 LOW
#   streak virus: 0.948 ✅ OK
# Low performance threshold: F1 <= 0.866
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.477
#   Client 1: Data=0.352, Perf=0.000 → Final=0.211
#   Client 2: Data=0.284, Perf=0.549 → Final=0.312
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 18 Global Results:
#   Overall Accuracy: 91.55%
#   Weighted F1 Score: 0.9151
#   Global Loss: 0.2305
#   Round Time: 292.5s
#   Per-class F1 scores:
#     fall armyworm: 0.984 good
#     grasshoper: 0.983 good
#     healthy: 0.895 good
#     leaf beetle: 0.992 good
#     leaf blight: 0.844 bad
#     leaf spot: 0.856 bad
#     streak virus: 0.945 good
#
# ============================================================
# ROUND 19/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 19: 93.4% accuracy, F1: 0.934, LR: 0.000168
# Training Maize Disease Client 1...
#   Client 1 Round 19: 93.3% accuracy, F1: 0.932, LR: 0.000168
# Training Maize Disease Client 2...
#   Client 2 Round 19: 90.6% accuracy, F1: 0.905, LR: 0.000168
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.951 ✅ OK
#   grasshoper: 0.970 ✅ OK
#   healthy: 0.871 ✅ OK
#   leaf beetle: 0.984 ✅ OK
#   leaf blight: 0.851 🔴 LOW
#   leaf spot: 0.825 🔴 LOW
#   streak virus: 0.952 ✅ OK
# Low performance threshold: F1 <= 0.861
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=0.378 → Final=0.331
#   Client 1: Data=0.352, Perf=0.000 → Final=0.221
#   Client 2: Data=0.284, Perf=1.000 → Final=0.448
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 19 Global Results:
#   Overall Accuracy: 91.88%
#   Weighted F1 Score: 0.9184
#   Global Loss: 0.2370
#   Round Time: 294.2s
#   Per-class F1 scores:
#     fall armyworm: 0.983 good
#     grasshoper: 0.983 good
#     healthy: 0.897 good
#     leaf beetle: 0.992 good
#     leaf blight: 0.858 bad
#     leaf spot: 0.857 bad
#     streak virus: 0.945 good
#
# ============================================================
# ROUND 20/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 20: 94.5% accuracy, F1: 0.945, LR: 0.000118
# Training Maize Disease Client 1...
#   Client 1 Round 20: 93.2% accuracy, F1: 0.931, LR: 0.000118
# Training Maize Disease Client 2...
#   Client 2 Round 20: 89.8% accuracy, F1: 0.898, LR: 0.000118
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.966 ✅ OK
#   grasshoper: 0.978 ✅ OK
#   healthy: 0.896 ✅ OK
#   leaf beetle: 0.985 ✅ OK
#   leaf blight: 0.856 🔴 LOW
#   leaf spot: 0.830 🔴 LOW
#   streak virus: 0.954 ✅ OK
# Low performance threshold: F1 <= 0.876
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.553
#   Client 1: Data=0.352, Perf=0.000 → Final=0.245
#   Client 2: Data=0.284, Perf=0.012 → Final=0.201
# ======================================================================
#
# Round 20 Global Results:
#   Overall Accuracy: 91.34%
#   Weighted F1 Score: 0.9127
#   Global Loss: 0.2513
#   Round Time: 291.9s
#   Per-class F1 scores:
#     fall armyworm: 0.993 good
#     grasshoper: 0.984 good
#     healthy: 0.897 good
#     leaf beetle: 0.993 good
#     leaf blight: 0.836 bad
#     leaf spot: 0.851 bad
#     streak virus: 0.942 good
#
# ============================================================
# ROUND 21/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 21: 94.1% accuracy, F1: 0.940, LR: 0.000118
# Training Maize Disease Client 1...
#   Client 1 Round 21: 93.5% accuracy, F1: 0.934, LR: 0.000118
# Training Maize Disease Client 2...
#   Client 2 Round 21: 89.6% accuracy, F1: 0.896, LR: 0.000118
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.946 ✅ OK
#   grasshoper: 0.972 ✅ OK
#   healthy: 0.888 ✅ OK
#   leaf beetle: 0.983 ✅ OK
#   leaf blight: 0.854 🔴 LOW
#   leaf spot: 0.825 🔴 LOW
#   streak virus: 0.953 ✅ OK
# Low performance threshold: F1 <= 0.871
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.520
#   Client 1: Data=0.352, Perf=0.227 → Final=0.294
#   Client 2: Data=0.284, Perf=0.000 → Final=0.186
# ======================================================================
#
# Round 21 Global Results:
#   Overall Accuracy: 91.30%
#   Weighted F1 Score: 0.9122
#   Global Loss: 0.2547
#   Round Time: 290.7s
#   Per-class F1 scores:
#     fall armyworm: 0.988 good
#     grasshoper: 0.988 good
#     healthy: 0.887 good
#     leaf beetle: 0.994 good
#     leaf blight: 0.839 bad
#     leaf spot: 0.850 bad
#     streak virus: 0.939 good
#
# ============================================================
# ROUND 22/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 22: 94.2% accuracy, F1: 0.942, LR: 0.000118
# Training Maize Disease Client 1...
#   Client 1 Round 22: 93.9% accuracy, F1: 0.938, LR: 0.000118
# Training Maize Disease Client 2...
#   Client 2 Round 22: 90.1% accuracy, F1: 0.901, LR: 0.000118
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.956 ✅ OK
#   grasshoper: 0.974 ✅ OK
#   healthy: 0.898 ✅ OK
#   leaf beetle: 0.986 ✅ OK
#   leaf blight: 0.858 🔴 LOW
#   leaf spot: 0.833 🔴 LOW
#   streak virus: 0.958 ✅ OK
# Low performance threshold: F1 <= 0.878
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.532
#   Client 1: Data=0.352, Perf=0.147 → Final=0.278
#   Client 2: Data=0.284, Perf=0.000 → Final=0.190
# ======================================================================
#
# Round 22 Global Results:
#   Overall Accuracy: 91.63%
#   Weighted F1 Score: 0.9157
#   Global Loss: 0.2570
#   Round Time: 293.0s
#   Per-class F1 scores:
#     fall armyworm: 0.991 good
#     grasshoper: 0.987 good
#     healthy: 0.903 good
#     leaf beetle: 0.993 good
#     leaf blight: 0.841 bad
#     leaf spot: 0.858 bad
#     streak virus: 0.943 good
#
# ============================================================
# ROUND 23/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 23: 94.7% accuracy, F1: 0.947, LR: 0.000082
# Training Maize Disease Client 1...
#   Client 1 Round 23: 94.1% accuracy, F1: 0.940, LR: 0.000082
# Training Maize Disease Client 2...
#   Client 2 Round 23: 88.9% accuracy, F1: 0.891, LR: 0.000082
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.958 ✅ OK
#   grasshoper: 0.971 ✅ OK
#   healthy: 0.886 ✅ OK
#   leaf beetle: 0.991 ✅ OK
#   leaf blight: 0.857 🔴 LOW
#   leaf spot: 0.832 🔴 LOW
#   streak virus: 0.960 ✅ OK
# Low performance threshold: F1 <= 0.872
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.471
#   Client 1: Data=0.352, Perf=0.596 → Final=0.360
#   Client 2: Data=0.284, Perf=0.000 → Final=0.168
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 23 Global Results:
#   Overall Accuracy: 91.92%
#   Weighted F1 Score: 0.9185
#   Global Loss: 0.2564
#   Round Time: 290.8s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.989 good
#     healthy: 0.908 good
#     leaf beetle: 0.993 good
#     leaf blight: 0.846 bad
#     leaf spot: 0.863 bad
#     streak virus: 0.945 good
#
# ============================================================
# ROUND 24/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 24: 95.3% accuracy, F1: 0.952, LR: 0.000082
# Training Maize Disease Client 1...
#   Client 1 Round 24: 94.1% accuracy, F1: 0.941, LR: 0.000082
# Training Maize Disease Client 2...
#   Client 2 Round 24: 89.4% accuracy, F1: 0.893, LR: 0.000082
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.958 ✅ OK
#   grasshoper: 0.980 ✅ OK
#   healthy: 0.906 ✅ OK
#   leaf beetle: 0.989 ✅ OK
#   leaf blight: 0.859 🔴 LOW
#   leaf spot: 0.837 🔴 LOW
#   streak virus: 0.959 ✅ OK
# Low performance threshold: F1 <= 0.882
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.502
#   Client 1: Data=0.352, Perf=0.351 → Final=0.318
#   Client 2: Data=0.284, Perf=0.000 → Final=0.180
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 24 Global Results:
#   Overall Accuracy: 91.98%
#   Weighted F1 Score: 0.9191
#   Global Loss: 0.2628
#   Round Time: 289.7s
#   Per-class F1 scores:
#     fall armyworm: 0.984 good
#     grasshoper: 0.992 good
#     healthy: 0.915 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.849 bad
#     leaf spot: 0.859 bad
#     streak virus: 0.946 good
#
# ============================================================
# ROUND 25/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 25: 94.6% accuracy, F1: 0.946, LR: 0.000082
# Training Maize Disease Client 1...
#   Client 1 Round 25: 93.6% accuracy, F1: 0.936, LR: 0.000082
# Training Maize Disease Client 2...
#   Client 2 Round 25: 89.2% accuracy, F1: 0.893, LR: 0.000082
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.952 ✅ OK
#   grasshoper: 0.970 ✅ OK
#   healthy: 0.883 ✅ OK
#   leaf beetle: 0.981 ✅ OK
#   leaf blight: 0.859 🔴 LOW
#   leaf spot: 0.833 🔴 LOW
#   streak virus: 0.956 ✅ OK
# Low performance threshold: F1 <= 0.871
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.506
#   Client 1: Data=0.352, Perf=0.323 → Final=0.313
#   Client 2: Data=0.284, Perf=0.000 → Final=0.181
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 25 Global Results:
#   Overall Accuracy: 92.08%
#   Weighted F1 Score: 0.9202
#   Global Loss: 0.2523
#   Round Time: 292.0s
#   Per-class F1 scores:
#     fall armyworm: 0.983 good
#     grasshoper: 0.992 good
#     healthy: 0.906 good
#     leaf beetle: 0.994 good
#     leaf blight: 0.851 bad
#     leaf spot: 0.863 bad
#     streak virus: 0.948 good
#
# ============================================================
# ROUND 26/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 26: 94.5% accuracy, F1: 0.944, LR: 0.000058
# Training Maize Disease Client 1...
#   Client 1 Round 26: 94.4% accuracy, F1: 0.943, LR: 0.000058
# Training Maize Disease Client 2...
#   Client 2 Round 26: 90.7% accuracy, F1: 0.907, LR: 0.000058
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.952 ✅ OK
#   grasshoper: 0.977 ✅ OK
#   healthy: 0.914 ✅ OK
#   leaf beetle: 0.988 ✅ OK
#   leaf blight: 0.865 🔴 LOW
#   leaf spot: 0.847 🔴 LOW
#   streak virus: 0.959 ✅ OK
# Low performance threshold: F1 <= 0.889
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.526
#   Client 1: Data=0.352, Perf=0.185 → Final=0.286
#   Client 2: Data=0.284, Perf=0.000 → Final=0.188
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 26 Global Results:
#   Overall Accuracy: 92.18%
#   Weighted F1 Score: 0.9210
#   Global Loss: 0.2579
#   Round Time: 292.3s
#   Per-class F1 scores:
#     fall armyworm: 0.986 good
#     grasshoper: 0.992 good
#     healthy: 0.911 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.847 bad
#     leaf spot: 0.866 bad
#     streak virus: 0.949 good
#
# ============================================================
# ROUND 27/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 27: 95.2% accuracy, F1: 0.952, LR: 0.000058
# Training Maize Disease Client 1...
#   Client 1 Round 27: 93.8% accuracy, F1: 0.937, LR: 0.000058
# Training Maize Disease Client 2...
#   Client 2 Round 27: 90.4% accuracy, F1: 0.904, LR: 0.000058
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.949 ✅ OK
#   grasshoper: 0.974 ✅ OK
#   healthy: 0.895 ✅ OK
#   leaf beetle: 0.987 ✅ OK
#   leaf blight: 0.872 🔴 LOW
#   leaf spot: 0.842 🔴 LOW
#   streak virus: 0.957 ✅ OK
# Low performance threshold: F1 <= 0.884
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ...
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 28: 94.4% accuracy, F1: 0.943, LR: 0.000058
# Training Maize Disease Client 1...
#   Client 1 Round 28: 94.0% accuracy, F1: 0.940, LR: 0.000058
# Training Maize Disease Client 2...
#   Client 2 Round 28: 90.4% accuracy, F1: 0.905, LR: 0.000058
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.953 ✅ OK
#   grasshoper: 0.971 ✅ OK
#   healthy: 0.914 ✅ OK
#   leaf beetle: 0.983 ✅ OK
#   leaf blight: 0.865 🔴 LOW
#   leaf spot: 0.840 🔴 LOW
#   streak virus: 0.958 ✅ OK
# Low performance threshold: F1 <= 0.890
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.555
#   Client 1: Data=0.352, Perf=0.000 → Final=0.246
#   Client 2: Data=0.284, Perf=0.000 → Final=0.199
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 28 Global Results:
#   Overall Accuracy: 92.27%
#   Weighted F1 Score: 0.9222
#   Global Loss: 0.2625
#   Round Time: 289.2s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.990 good
#     healthy: 0.910 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.855 bad
#     leaf spot: 0.861 bad
#     streak virus: 0.953 good
#
# ============================================================
# ROUND 29/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 29: 95.3% accuracy, F1: 0.953, LR: 0.000040
# Training Maize Disease Client 1...
#   Client 1 Round 29: 93.6% accuracy, F1: 0.935, LR: 0.000040
# Training Maize Disease Client 2...
#   Client 2 Round 29: 90.1% accuracy, F1: 0.901, LR: 0.000040
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.948 ✅ OK
#   grasshoper: 0.974 ✅ OK
#   healthy: 0.888 ✅ OK
#   leaf beetle: 0.989 ✅ OK
#   leaf blight: 0.861 🔴 LOW
#   leaf spot: 0.844 🔴 LOW
#   streak virus: 0.956 ✅ OK
# Low performance threshold: F1 <= 0.875
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.532
#   Client 1: Data=0.352, Perf=0.000 → Final=0.236
#   Client 2: Data=0.284, Perf=0.149 → Final=0.233
# ======================================================================
#
# Round 29 Global Results:
#   Overall Accuracy: 92.18%
#   Weighted F1 Score: 0.9211
#   Global Loss: 0.2637
#   Round Time: 290.9s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.990 good
#     healthy: 0.914 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.850 bad
#     leaf spot: 0.862 bad
#     streak virus: 0.951 good
#
# ============================================================
# ROUND 30/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 30: 95.2% accuracy, F1: 0.952, LR: 0.000040
# Training Maize Disease Client 1...
#   Client 1 Round 30: 93.6% accuracy, F1: 0.935, LR: 0.000040
# Training Maize Disease Client 2...
#   Client 2 Round 30: 89.8% accuracy, F1: 0.898, LR: 0.000040
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.935 ✅ OK
#   grasshoper: 0.976 ✅ OK
#   healthy: 0.901 ✅ OK
#   leaf beetle: 0.990 ✅ OK
#   leaf blight: 0.864 🔴 LOW
#   leaf spot: 0.834 🔴 LOW
#   streak virus: 0.957 ✅ OK
# Low performance threshold: F1 <= 0.883
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.547
#   Client 1: Data=0.352, Perf=0.051 → Final=0.257
#   Client 2: Data=0.284, Perf=0.000 → Final=0.196
# ======================================================================
#
# Round 30 Global Results:
#   Overall Accuracy: 92.16%
#   Weighted F1 Score: 0.9209
#   Global Loss: 0.2644
#   Round Time: 289.0s
#   Per-class F1 scores:
#     fall armyworm: 0.988 good
#     grasshoper: 0.990 good
#     healthy: 0.916 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.849 bad
#     leaf spot: 0.863 bad
#     streak virus: 0.950 good
#
# ============================================================
# ROUND 31/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 31: 95.2% accuracy, F1: 0.951, LR: 0.000040
# Training Maize Disease Client 1...
#   Client 1 Round 31: 93.9% accuracy, F1: 0.939, LR: 0.000040
# Training Maize Disease Client 2...
#   Client 2 Round 31: 90.4% accuracy, F1: 0.904, LR: 0.000040
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.954 ✅ OK
#   grasshoper: 0.977 ✅ OK
#   healthy: 0.926 ✅ OK
#   leaf beetle: 0.995 ✅ OK
#   leaf blight: 0.865 🔴 LOW
#   leaf spot: 0.840 🔴 LOW
#   streak virus: 0.954 ✅ OK
# Low performance threshold: F1 <= 0.896
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.518
#   Client 1: Data=0.352, Perf=0.000 → Final=0.229
#   Client 2: Data=0.284, Perf=0.242 → Final=0.253
# ======================================================================
#
# Round 31 Global Results:
#   Overall Accuracy: 92.21%
#   Weighted F1 Score: 0.9215
#   Global Loss: 0.2643
#   Round Time: 291.5s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.990 good
#     healthy: 0.911 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.852 bad
#     leaf spot: 0.863 bad
#     streak virus: 0.950 good
#
# ============================================================
# ROUND 32/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 32: 95.5% accuracy, F1: 0.955, LR: 0.000028
# Training Maize Disease Client 1...
#   Client 1 Round 32: 94.4% accuracy, F1: 0.943, LR: 0.000028
# Training Maize Disease Client 2...
#   Client 2 Round 32: 89.4% accuracy, F1: 0.894, LR: 0.000028
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.940 ✅ OK
#   grasshoper: 0.974 ✅ OK
#   healthy: 0.937 ✅ OK
#   leaf beetle: 0.988 ✅ OK
#   leaf blight: 0.875 🔴 LOW
#   leaf spot: 0.843 🔴 LOW
#   streak virus: 0.955 ✅ OK
# Low performance threshold: F1 <= 0.906
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.483
#   Client 1: Data=0.352, Perf=0.498 → Final=0.344
#   Client 2: Data=0.284, Perf=0.000 → Final=0.173
# ======================================================================
#
# Round 32 Global Results:
#   Overall Accuracy: 92.21%
#   Weighted F1 Score: 0.9215
#   Global Loss: 0.2702
#   Round Time: 289.1s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.990 good
#     healthy: 0.914 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.845 bad
#     leaf spot: 0.864 bad
#     streak virus: 0.954 good
#
# ============================================================
# ROUND 33/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 33: 95.0% accuracy, F1: 0.950, LR: 0.000028
# Training Maize Disease Client 1...
#   Client 1 Round 33: 93.9% accuracy, F1: 0.938, LR: 0.000028
# Training Maize Disease Client 2...
#   Client 2 Round 33: 89.0% accuracy, F1: 0.891, LR: 0.000028
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.938 ✅ OK
#   grasshoper: 0.967 ✅ OK
#   healthy: 0.890 ✅ OK
#   leaf beetle: 0.987 ✅ OK
#   leaf blight: 0.861 🔴 LOW
#   leaf spot: 0.844 🔴 LOW
#   streak virus: 0.952 ✅ OK
# Low performance threshold: F1 <= 0.875
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.512
#   Client 1: Data=0.352, Perf=0.285 → Final=0.305
#   Client 2: Data=0.284, Perf=0.000 → Final=0.183
# ======================================================================
#
# Round 33 Global Results:
#   Overall Accuracy: 92.27%
#   Weighted F1 Score: 0.9221
#   Global Loss: 0.2713
#   Round Time: 286.7s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.989 good
#     healthy: 0.917 good
#     leaf beetle: 0.994 good
#     leaf blight: 0.851 bad
#     leaf spot: 0.866 bad
#     streak virus: 0.951 good
#
# ============================================================
# ROUND 34/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 34: 94.8% accuracy, F1: 0.948, LR: 0.000028
# Training Maize Disease Client 1...
#   Client 1 Round 34: 94.1% accuracy, F1: 0.941, LR: 0.000028
# Training Maize Disease Client 2...
#   Client 2 Round 34: 89.4% accuracy, F1: 0.895, LR: 0.000028
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.930 ✅ OK
#   grasshoper: 0.980 ✅ OK
#   healthy: 0.933 ✅ OK
#   leaf beetle: 0.988 ✅ OK
#   leaf blight: 0.863 🔴 LOW
#   leaf spot: 0.837 🔴 LOW
#   streak virus: 0.955 ✅ OK
# Low performance threshold: F1 <= 0.897
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.471
#   Client 1: Data=0.352, Perf=0.594 → Final=0.360
#   Client 2: Data=0.284, Perf=0.000 → Final=0.169
# ======================================================================
#
# Round 34 Global Results:
#   Overall Accuracy: 92.25%
#   Weighted F1 Score: 0.9220
#   Global Loss: 0.2716
#   Round Time: 290.4s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.990 good
#     healthy: 0.911 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.851 bad
#     leaf spot: 0.865 bad
#     streak virus: 0.951 good
#
# ============================================================
# ROUND 35/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 35: 94.8% accuracy, F1: 0.947, LR: 0.000020
# Training Maize Disease Client 1...
#   Client 1 Round 35: 93.8% accuracy, F1: 0.937, LR: 0.000020
# Training Maize Disease Client 2...
#   Client 2 Round 35: 89.7% accuracy, F1: 0.897, LR: 0.000020
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.948 ✅ OK
#   grasshoper: 0.971 ✅ OK
#   healthy: 0.906 ✅ OK
#   leaf beetle: 0.989 ✅ OK
#   leaf blight: 0.861 🔴 LOW
#   leaf spot: 0.837 🔴 LOW
#   streak virus: 0.954 ✅ OK
# Low performance threshold: F1 <= 0.883
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.493
#   Client 1: Data=0.352, Perf=0.422 → Final=0.331
#   Client 2: Data=0.284, Perf=0.000 → Final=0.176
# ======================================================================
#   🎯 New best accuracy! Model saved.
#
# Round 35 Global Results:
#   Overall Accuracy: 92.41%
#   Weighted F1 Score: 0.9235
#   Global Loss: 0.2768
#   Round Time: 289.3s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.989 good
#     healthy: 0.913 good
#     leaf beetle: 0.994 good
#     leaf blight: 0.854 bad
#     leaf spot: 0.868 bad
#     streak virus: 0.952 good
#
# ============================================================
# ROUND 36/36
# ============================================================
# Training Maize Disease Client 0...
#   Client 0 Round 36: 95.0% accuracy, F1: 0.950, LR: 0.000020
# Training Maize Disease Client 1...
#   Client 1 Round 36: 94.1% accuracy, F1: 0.941, LR: 0.000020
# Training Maize Disease Client 2...
#   Client 2 Round 36: 88.3% accuracy, F1: 0.884, LR: 0.000020
#
# Performing Adaptive Dynamic Weighted Aggregation...
# Global F1 scores per maize disease class:
#   fall armyworm: 0.944 ✅ OK
#   grasshoper: 0.971 ✅ OK
#   healthy: 0.899 ✅ OK
#   leaf beetle: 0.983 ✅ OK
#   leaf blight: 0.863 🔴 LOW
#   leaf spot: 0.831 🔴 LOW
#   streak virus: 0.954 ✅ OK
# Low performance threshold: F1 <= 0.881
# Low-performing classes: ['leaf blight', 'leaf spot']
#
# ======================================================================
# ADAPTIVE DYNAMIC WEIGHTED AGGREGATION SUMMARY
# ======================================================================
# Focus Strategy: Bottom 30% of classes by F1 score
# Data vs Performance Weight Balance: 0.7 / 0.3
# Low-performing classes targeted: 2
# Targeted diseases: leaf blight, leaf spot
#
# Client Weight Distribution:
#   Client 0: Data=0.365, Perf=1.000 → Final=0.470
#   Client 1: Data=0.352, Perf=0.607 → Final=0.362
#   Client 2: Data=0.284, Perf=0.000 → Final=0.168
# ======================================================================
#
# Round 36 Global Results:
#   Overall Accuracy: 92.37%
#   Weighted F1 Score: 0.9231
#   Global Loss: 0.2739
#   Round Time: 290.8s
#   Per-class F1 scores:
#     fall armyworm: 0.989 good
#     grasshoper: 0.990 good
#     healthy: 0.913 good
#     leaf beetle: 0.995 good
#     leaf blight: 0.851 bad
#     leaf spot: 0.867 bad
#     streak virus: 0.953 good
#
# ================================================================================
# ADAPTIVE MAIZE DISEASE FEDERATED LEARNING COMPLETED
# ================================================================================
# Final Accuracy: 92.37%
# Best Accuracy: 92.41%
# Improvement from adaptive aggregation: Focus on challenging diseases
# Model size: 18.71 MB (Edge ready: Yes)

# %%
# Cell 13: Confusion Matrix and ROC Curve Evaluation
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
import torch.nn.functional as F

def evaluate_model_with_cm_roc(model, test_loader, class_names, device):
    """
    Create confusion matrix and ROC curves for the trained model
    """
    model.eval()
    all_preds = []
    all_targets = []
    all_probs = []
    
    print("Collecting predictions from test set...")
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            
            # Get probabilities using softmax
            probs = F.softmax(output, dim=1)
            all_probs.extend(probs.cpu().numpy())
            
            # Get predicted classes
            preds = output.argmax(1)
            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(target.cpu().numpy())
    
    all_preds = np.array(all_preds)
    all_targets = np.array(all_targets)
    all_probs = np.array(all_probs)
    
    # 1. CONFUSION MATRIX - Simple Format
    print("\n" + "="*60)
    print("CONFUSION MATRIX EVALUATION")
    print("="*60)
    
    cm = confusion_matrix(all_targets, all_preds)
    
    # For binary-style reporting, we can show overall TP, FP, TN, FN
    if len(class_names) == 2:
        # True binary classification
        tn, fp, fn, tp = cm.ravel()
        print(f"\nBinary Classification Metrics:")
        print(f"True Positives (TP): {tp}")
        print(f"False Positives (FP): {fp}")
        print(f"True Negatives (TN): {tn}")
        print(f"False Negatives (FN): {fn}")
        
        # Simple 2x2 confusion matrix
        fig, ax = plt.subplots(1, 1, figsize=(8, 6))
        sns.heatmap([[tn, fp], [fn, tp]], 
                    annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Predicted Negative', 'Predicted Positive'],
                    yticklabels=['Actual Negative', 'Actual Positive'],
                    ax=ax)
        ax.set_title('Binary Confusion Matrix\n(TN, FP, FN, TP Format)', fontsize=14)
        plt.tight_layout()
        plt.show()
    
    else:
        # Multi-class: Show overall metrics by treating as binary (diseased vs healthy)
        # Assuming class 0 is "Healthy" and others are "Diseased"
        binary_targets = (all_targets > 0).astype(int)  # 0=Healthy, 1=Diseased
        binary_preds = (all_preds > 0).astype(int)
        
        tn = np.sum((binary_targets == 0) & (binary_preds == 0))
        fp = np.sum((binary_targets == 0) & (binary_preds == 1))
        fn = np.sum((binary_targets == 1) & (binary_preds == 0))
        tp = np.sum((binary_targets == 1) & (binary_preds == 1))
        
        print(f"\nOverall Disease Detection Metrics (Healthy vs Diseased):")
        print(f"True Positives (TP - Correctly identified diseased): {tp}")
        print(f"False Positives (FP - Healthy classified as diseased): {fp}")
        print(f"True Negatives (TN - Correctly identified healthy): {tn}")
        print(f"False Negatives (FN - Diseased classified as healthy): {fn}")
        
        # Simple 2x2 confusion matrix for disease detection
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
        
        # Binary confusion matrix
        sns.heatmap([[tn, fp], [fn, tp]], 
                    annot=True, fmt='d', cmap='Blues',
                    xticklabels=['Predicted Healthy', 'Predicted Diseased'],
                    yticklabels=['Actual Healthy', 'Actual Diseased'],
                    ax=ax1)
        ax1.set_title('Binary Disease Detection\nConfusion Matrix', fontsize=12)
        
        # Multi-class confusion matrix
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                    xticklabels=class_names, yticklabels=class_names,
                    ax=ax2)
        ax2.set_title('Multi-class Confusion Matrix', fontsize=12)
        ax2.set_xlabel('Predicted Class')
        ax2.set_ylabel('Actual Class')
        
        plt.tight_layout()
        plt.show()
    
    # Calculate accuracy and other metrics
    accuracy = np.sum(all_preds == all_targets) / len(all_targets)
    print(f"\nOverall Accuracy: {accuracy*100:.2f}%")
    
    # 2. ROC CURVES
    print("\n" + "="*60)
    print("ROC CURVE ANALYSIS")
    print("="*60)
    
    n_classes = len(class_names)
    
    if n_classes == 2:
        # Binary ROC curve
        fpr, tpr, _ = roc_curve(all_targets, all_probs[:, 1])
        roc_auc = auc(fpr, tpr)
        
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, color='darkorange', lw=2, 
                 label=f'ROC curve (AUC = {roc_auc:.2f})')
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', 
                 label='Random Classifier')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic (ROC) Curve')
        plt.legend(loc="lower right")
        plt.grid(True, alpha=0.3)
        plt.show()
        
        print(f"Binary Classification AUC: {roc_auc:.3f}")
    
    else:
        # Multi-class ROC curves (One-vs-Rest approach)
        # Binarize the targets for multi-class ROC
        targets_binarized = label_binarize(all_targets, classes=list(range(n_classes)))
        
        # Compute ROC curve and AUC for each class
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        
        plt.figure(figsize=(12, 8))
        
        colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink']
        
        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(targets_binarized[:, i], all_probs[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])
            
            plt.plot(fpr[i], tpr[i], color=colors[i % len(colors)], lw=2,
                     label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')
        
        plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random Classifier')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate', fontsize=12)
        plt.ylabel('True Positive Rate', fontsize=12)
        plt.title('Multi-class ROC Curves (One-vs-Rest)', fontsize=14)
        plt.legend(loc="lower right")
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()
        
        # Print AUC scores
        print(f"\nPer-class AUC Scores:")
        for i, class_name in enumerate(class_names):
            print(f"  {class_name}: {roc_auc[i]:.3f}")
        
        # Calculate macro and micro average AUC
        macro_auc = np.mean(list(roc_auc.values()))
        print(f"\nMacro-average AUC: {macro_auc:.3f}")
    
    # 3. DETAILED CLASSIFICATION REPORT
    print("\n" + "="*60)
    print("DETAILED CLASSIFICATION REPORT")
    print("="*60)
    print(classification_report(all_targets, all_preds, target_names=class_names))
    
    return {
        'confusion_matrix': cm,
        'accuracy': accuracy,
        'predictions': all_preds,
        'targets': all_targets,
        'probabilities': all_probs,
        'roc_auc': roc_auc if n_classes > 2 else roc_auc
    }

# Usage after your federated learning training is complete:
print("Evaluating the final federated learning model...")

# Evaluate the final model
results = evaluate_model_with_cm_roc(
    model=final_model, 
    test_loader=maize_test_loader, 
    class_names=MAIZE_CLASS_NAMES, 
    device=device
)

print("Model evaluation completed!")
# Out:
# Evaluating the final federated learning model...
# Collecting predictions from test set...
#
# ============================================================
# CONFUSION MATRIX EVALUATION
# ============================================================
#
# Overall Disease Detection Metrics (Healthy vs Diseased):
# True Positives (TP - Correctly identified diseased): 4837
# False Positives (FP - Healthy classified as diseased): 2
# True Negatives (TN - Correctly identified healthy): 282
# False Negatives (FN - Diseased classified as healthy): 4
# Overall Accuracy: 92.37%
#
# ============================================================
# ROC CURVE ANALYSIS
# ============================================================
# Per-class AUC Scores:
#   fall armyworm: 1.000
#   grasshoper: 1.000
#   healthy: 0.996
#   leaf beetle: 1.000
#   leaf blight: 0.983
#   leaf spot: 0.977
#   streak virus: 0.997
#
# Macro-average AUC: 0.993
#
# ============================================================
# DETAILED CLASSIFICATION REPORT
# ============================================================
#                precision    recall  f1-score   support
#
# fall armyworm       0.99      0.99      0.99       284
#    grasshoper       0.99      1.00      0.99       411
#       healthy       0.86      0.97      0.91       211
#   leaf beetle       0.99      0.99      0.99       950
#   leaf blight       0.87      0.83      0.85      1004
#     leaf spot       0.88      0.85      0.87      1261
#  streak virus       0.93      0.98      0.95      1004
#
#      accuracy                           0.92      5125
#     macro avg       0.93      0.94      0.94      5125
#  weighted avg       0.92      0.92      0.92      5125
#
# Model evaluation completed!

# %%
# Cell 14: Fixed Final Model Testing, Quantization, Edge Validation
def test_final_maize_disease_model(final_model):
    print("="*70)
    print("TESTING FINAL MAIZE DISEASE DETECTION MODEL")
    print("="*70)

    # Ensure model is on correct device and in eval mode
    final_model = final_model.to(device)
    final_model.eval()

    # Verify model device
    model_device = next(final_model.parameters()).device
    print(f"Model device: {model_device}")

    all_preds, all_targets = [], []
    with torch.no_grad():
        for data, target in maize_test_loader:
            # Ensure data is on same device as model
            data, target = data.to(device), target.to(device)
            output = final_model(data)
            preds = output.argmax(1)
            all_preds.extend(preds.cpu().numpy())
            all_targets.extend(target.cpu().numpy())

    from sklearn.metrics import classification_report
    report = classification_report(all_targets, all_preds, target_names=MAIZE_CLASS_NAMES, output_dict=True)
    print("Per-class accuracy/F1:")
    for cls in MAIZE_CLASS_NAMES:
        print(f"{cls}: Acc={report[cls]['recall']:.2f}, F1={report[cls]['f1-score']:.2f}")
    print(f"Overall accuracy: {report['accuracy']:.2f}")

    # Quantization for edge deployment - MOVE MODEL TO CPU FIRST
    print("\nPreparing model for quantization...")

    # Move model to CPU for quantization
    cpu_model = final_model.cpu()
    cpu_model.eval()

    # Quantize the CPU model
    quantized_model = cpu_model.quantize_dynamic()

    # Save quantized model
    import os
    torch.save(quantized_model.state_dict(), "quantized_model.pth")
    size_mb = os.path.getsize("quantized_model.pth")/1024/1024
    print(f"Quantized model size: {size_mb:.2f} MB")

    # Edge inference speed test (simulate RPi4) - CPU inference
    print("Testing inference speed on CPU (simulating edge device)...")
    import time

    # Create CPU input for testing
    dummy_input = torch.randn(1, 3, 224, 224)  # CPU tensor by default

    # Warm up
    for _ in range(3):
        with torch.no_grad():
            _ = quantized_model(dummy_input)

    # Measure latency
    start = time.time()
    with torch.no_grad():
        for _ in range(10):
            _ = quantized_model(dummy_input)
    latency = (time.time() - start) / 10 * 1000
    print(f"Simulated inference latency: {latency:.1f} ms (target <100ms)")

    # Test accuracy of quantized model on a small subset
    print("Testing quantized model accuracy...")
    quantized_model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for i, (data, target) in enumerate(maize_test_loader):
            if i >= 5:  # Test on first 5 batches only
                break
            # Keep data on CPU for quantized model
            data_cpu = data.cpu()
            target_cpu = target.cpu()

            output = quantized_model(data_cpu)
            _, predicted = output.max(1)
            total += target_cpu.size(0)
            correct += predicted.eq(target_cpu).sum().item()

    quantized_accuracy = correct / total if total > 0 else 0
    print(f"Quantized model accuracy (sample): {quantized_accuracy*100:.2f}%")

    # Move original model back to GPU if needed
    final_model = final_model.to(device)

    return report, size_mb, latency

# After FL rounds - ensure final_model exists and is properly defined
if 'final_model' in locals():
    final_report, quant_size, quant_latency = test_final_maize_disease_model(final_model)
else:
    print("Error: final_model not found. Please run the federated learning cell first.")

# %%
# Cell: Fixed Maize Disease Prediction Function for Kaggle
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torchvision import transforms
from IPython.display import display
import ipywidgets as widgets
import io

def predict_maize_disease(model, image_data, class_names, img_size=224):
    """Make a prediction on a new maize disease image"""

    # Load image from uploaded data
    img = Image.open(io.BytesIO(image_data)).convert('RGB')

    # Define transform (same as training)
    transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

    # Preprocess image
    img_tensor = transform(img).unsqueeze(0)  # Add batch dimension

    # Move to device
    device = next(model.parameters()).device
    img_tensor = img_tensor.to(device)

    # Set model to eval mode
    model.eval()

    # Make prediction
    with torch.no_grad():
        output = model(img_tensor)
        probabilities = torch.nn.functional.softmax(output, dim=1)
        confidence, predicted_idx = torch.max(probabilities, 1)

        # Get top 3 predictions
        top3_prob, top3_idx = torch.topk(probabilities, 3, dim=1)

    predicted_class = class_names[predicted_idx.item()]
    confidence_score = confidence.item()

    # Visualize prediction
    plt.figure(figsize=(12, 5))

    # Original image
    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title(f"Uploaded Maize Image", fontsize=14, fontweight='bold')
    plt.axis('off')

    # Prediction results
    plt.subplot(1, 2, 2)

    # Create bar chart for top 3 predictions
    top3_classes = [class_names[idx.item()] for idx in top3_idx[0]]
    top3_probs = [prob.item() for prob in top3_prob[0]]

    colors = ['red' if i == 0 else 'lightblue' for i in range(3)]
    bars = plt.barh(range(3), top3_probs, color=colors)
    plt.yticks(range(3), top3_classes)
    plt.xlabel('Confidence Score')
    plt.title('Top 3 Predictions', fontsize=14, fontweight='bold')
    plt.xlim(0, 1)

    # Add percentage labels
    for i, (bar, prob) in enumerate(zip(bars, top3_probs)):
        plt.text(prob + 0.01, bar.get_y() + bar.get_height()/2,
                f'{prob*100:.1f}%', va='center', fontweight='bold')

    plt.tight_layout()
    plt.show()

    # Print detailed results
    print(f"🌽 MAIZE DISEASE PREDICTION RESULTS")
    print(f"{'='*50}")
    print(f"Primary Diagnosis: {predicted_class}")
    print(f"Confidence: {confidence_score*100:.2f}%")
    print(f"\nTop 3 Predictions:")
    for i, (cls, prob) in enumerate(zip(top3_classes, top3_probs)):
        print(f"  {i+1}. {cls}: {prob*100:.1f}%")

    # Agricultural recommendation
    print(f"\n🌾 AGRICULTURAL RECOMMENDATION:")
    if predicted_class.lower() == 'healthy':
        print("✅ Your maize plant appears healthy!")
        print("   Continue current management practices.")
    else:
        print(f"⚠️  {predicted_class} detected in your maize plant.")
        print("   Consult with agricultural extension officer.")
        print("   Consider appropriate treatment measures.")

    return predicted_class, confidence_score, top3_classes, top3_probs

# Fixed Kaggle Image Upload Widget
def create_maize_disease_predictor(model, class_names):
    """Create interactive maize disease predictor for Kaggle - FIXED VERSION"""

    print("🌽 MAIZE DISEASE DETECTION SYSTEM")
    print("="*50)
    print("Upload an image of a maize leaf to detect diseases")

    # File upload widget
    upload_widget = widgets.FileUpload(
        accept='image/*',
        multiple=False,
        description='Upload Maize Image'
    )

    # Output widget for results
    output_widget = widgets.Output()

    def on_upload_change(change):
        """Handle image upload and prediction - FIXED"""
        with output_widget:
            output_widget.clear_output()

            # Check if files were uploaded
            if upload_widget.value:
                try:
                    # Get the uploaded file - FIXED handling
                    uploaded_files = upload_widget.value

                    # Handle different upload widget value structures
                    if isinstance(uploaded_files, tuple):
                        # If it's a tuple, get the first element
                        if len(uploaded_files) > 0:
                            file_info = uploaded_files[0]
                            if hasattr(file_info, 'content'):
                                image_data = file_info.content
                            else:
                                image_data = file_info
                        else:
                            print("No file uploaded")
                            return
                    elif isinstance(uploaded_files, dict):
                        # If it's a dictionary, get the first value
                        file_info = list(uploaded_files.values())[0]
                        image_data = file_info['content']
                    else:
                        # Direct content
                        image_data = uploaded_files

                    print("Processing uploaded image...")

                    # Make prediction
                    predicted_class, confidence, top3_classes, top3_probs = predict_maize_disease(
                        model, image_data, class_names
                    )

                except Exception as e:
                    print(f"Error processing image: {e}")
                    print("Please upload a valid image file (JPG, PNG, etc.)")
                    print(f"Upload widget value type: {type(upload_widget.value)}")
                    if upload_widget.value:
                        print(f"Upload widget value: {upload_widget.value}")

    # Attach event handler
    upload_widget.observe(on_upload_change, names='value')

    # Display widgets
    display(upload_widget)
    display(output_widget)

    return upload_widget, output_widget

# Alternative Simple Upload Method (More Reliable for Kaggle)
def simple_upload_predictor(model, class_names):
    """Simple upload method that works better in Kaggle"""

    print("🌽 SIMPLE MAIZE DISEASE PREDICTOR")
    print("="*40)

    # Create upload widget
    uploader = widgets.FileUpload(
        accept='image/*',
        multiple=False
    )

    # Create button to trigger prediction
    predict_button = widgets.Button(
        description='Predict Disease',
        button_style='success',
        icon='check'
    )

    # Output area
    output = widgets.Output()

    def predict_clicked(b):
        with output:
            output.clear_output()

            if not uploader.value:
                print("Please upload an image first!")
                return

            try:
                # Get uploaded file content
                filename = list(uploader.value.keys())[0]
                content = uploader.value[filename]['content']

                print(f"Processing: {filename}")

                # Make prediction
                predicted_class, confidence, top3_classes, top3_probs = predict_maize_disease(
                    model, content, class_names
                )

            except Exception as e:
                print(f"Error: {e}")
                print("Please try uploading the image again.")

    predict_button.on_click(predict_clicked)

    # Display interface
    display(widgets.VBox([
        widgets.HTML("<h3>Step 1: Upload Image</h3>"),
        uploader,
        widgets.HTML("<h3>Step 2: Click Predict</h3>"),
        predict_button,
        widgets.HTML("<h3>Results:</h3>"),
        output
    ]))

# Usage - Choose one of these methods:

# Method 1: Try the fixed version first
print("Creating Maize Disease Prediction System (Fixed Version)...")
try:
    upload_widget, output_widget = create_maize_disease_predictor(final_model, MAIZE_CLASS_NAMES)
except:
    print("Fixed version failed, trying simple version...")
    # Method 2: Use simple version if fixed version doesn't work
    simple_upload_predictor(final_model, MAIZE_CLASS_NAMES)
